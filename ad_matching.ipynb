# %% [markdown]
# # Algorithms for Data Science

# %% [markdown]
# ## Matching Bids to Queries

# %% [markdown]
# ### 1. Preliminaries
#
# The objective of this lab is to implement the Adwords algorithm in the particular case when we have $N$ advertisers having budget $B$ and each bidding an amount of $1$. Moreover, queries arrive in batches of $B$ queries, $N$ times, and only advertises $A_i,\dots,A_n$ bid on round $i$. The optimal algorithm would have revenue $NB$. Our aim is to see what the revenue of the BALANCE algorithm is.

# %%
import random
import numpy as np
import math
#parameters
N = 10
B = 10

# %% [markdown]
# ### 2. BALANCE algorithm
#
# The balance algorithm simply gives the query to the bidder having the most budget available. In this case, BALANCE achieves a competitive ratio of $1-1/e$.

# %%
# array of budgets
Bs = [B]*N
revenue = 0

for i in range(N): #rounds
  for j in range(B): #queries
    idx = np.argmax(Bs[i:]) # taking the index with the most budget
    #print (Bs[i:])
    if Bs[i+idx]>0:
      Bs[i+idx] -= 1
      revenue += 1
      print (f'Round {i} query {j} -- allocated to bidder {i+idx}')
    else:
      print (f'Round {i} query {j} -- not allocated')

print (f'Total revenue: {revenue}')
# Out:
# Round 0 query 0 -- allocated to bidder 0
# Round 0 query 1 -- allocated to bidder 1
# Round 0 query 2 -- allocated to bidder 2
# Round 0 query 3 -- allocated to bidder 3
# Round 0 query 4 -- allocated to bidder 4
# Round 0 query 5 -- allocated to bidder 5
# Round 0 query 6 -- allocated to bidder 6
# Round 0 query 7 -- allocated to bidder 7
# Round 0 query 8 -- allocated to bidder 8
# Round 0 query 9 -- allocated to bidder 9
# Round 1 query 0 -- allocated to bidder 1
# Round 1 query 1 -- allocated to bidder 2
# Round 1 query 2 -- allocated to bidder 3
# Round 1 query 3 -- allocated to bidder 4
# Round 1 query 4 -- allocated to bidder 5
# Round 1 query 5 -- allocated to bidder 6
# Round 1 query 6 -- allocated to bidder 7
# Round 1 query 7 -- allocated to bidder 8
# Round 1 query 8 -- allocated to bidder 9
# Round 1 query 9 -- allocated to bidder 1
# Round 2 query 0 -- allocated to bidder 2
# Round 2 query 1 -- allocated to bidder 3
# Round 2 query 2 -- allocated to bidder 4
# Round 2 query 3 -- allocated to bidder 5
# Round 2 query 4 -- allocated to bidder 6
# Round 2 query 5 -- allocated to bidder 7
# Round 2 query 6 -- allocated to bidder 8
# Round 2 query 7 -- allocated to bidder 9
# Round 2 query 8 -- allocated to bidder 2
# Round 2 query 9 -- allocated to bidder 3
# Round 3 query 0 -- allocated to bidder 4
# Round 3 query 1 -- allocated to bidder 5
# Round 3 query 2 -- allocated to bidder 6
# Round 3 query 3 -- allocated to bidder 7
# Round 3 query 4 -- allocated to bidder 8
# Round 3 query 5 -- allocated to bidder 9
# Round 3 query 6 -- allocated to bidder 3
# Round 3 query 7 -- allocated to bidder 4
# Round 3 query 8 -- allocated to bidder 5
# Round 3 query 9 -- allocated to bidder 6
# Round 4 query 0 -- allocated to bidder 7
# Round 4 query 1 -- allocated to bidder 8
# Round 4 query 2 -- allocated to bidder 9
# Round 4 query 3 -- allocated to bidder 4
# Round 4 query 4 -- allocated to bidder 5
# Round 4 query 5 -- allocated to bidder 6
# Round 4 query 6 -- allocated to bidder 7
# Round 4 query 7 -- allocated to bidder 8
# Round 4 query 8 -- allocated to bidder 9
# Round 4 query 9 -- allocated to bidder 4
# Round 5 query 0 -- allocated to bidder 5
# Round 5 query 1 -- allocated to bidder 6
# Round 5 query 2 -- allocated to bidder 7
# Round 5 query 3 -- allocated to bidder 8
# Round 5 query 4 -- allocated to bidder 9
# Round 5 query 5 -- allocated to bidder 5
# Round 5 query 6 -- allocated to bidder 6
# Round 5 query 7 -- allocated to bidder 7
# Round 5 query 8 -- allocated to bidder 8
# Round 5 query 9 -- allocated to bidder 9
# Round 6 query 0 -- allocated to bidder 6
# Round 6 query 1 -- allocated to bidder 7
# Round 6 query 2 -- allocated to bidder 8
# Round 6 query 3 -- allocated to bidder 9
# Round 6 query 4 -- allocated to bidder 6
# Round 6 query 5 -- allocated to bidder 7
# Round 6 query 6 -- allocated to bidder 8
# Round 6 query 7 -- allocated to bidder 9
# Round 6 query 8 -- not allocated
# Round 6 query 9 -- not allocated
# Round 7 query 0 -- not allocated
# Round 7 query 1 -- not allocated
# Round 7 query 2 -- not allocated
# Round 7 query 3 -- not allocated
# Round 7 query 4 -- not allocated
# Round 7 query 5 -- not allocated
# Round 7 query 6 -- not allocated
# Round 7 query 7 -- not allocated
# Round 7 query 8 -- not allocated
# Round 7 query 9 -- not allocated
# Round 8 query 0 -- not allocated
# Round 8 query 1 -- not allocated
# Round 8 query 2 -- not allocated
# Round 8 query 3 -- not allocated
# Round 8 query 4 -- not allocated
# Round 8 query 5 -- not allocated
# Round 8 query 6 -- not allocated
# Round 8 query 7 -- not allocated
# Round 8 query 8 -- not allocated
# Round 8 query 9 -- not allocated
# Round 9 query 0 -- not allocated
# Round 9 query 1 -- not allocated
# Round 9 query 2 -- not allocated
# Round 9 query 3 -- not allocated
# Round 9 query 4 -- not allocated
# Round 9 query 5 -- not allocated
# Round 9 query 6 -- not allocated
# Round 9 query 7 -- not allocated
# Round 9 query 8 -- not allocated
# Round 9 query 9 -- not allocated
# Total revenue: 68

# %% [markdown]
# ### 3. **TASK** Generalized BALANCE Algorithm
#
# Implement the generalized BALANCE algorithm, where the bids can be arbitrary, and the bidder is selected based on the $\psi$ function presented in the lecture.

# %%
# YOUR CODE HERE

# let's identify the query by a number / id

# prices of bids are between 2 and 20
# number of possible bids for each bidder is between 3 and 30
class bidder:
    def __init__(self, id_bidder, bid_price, budget):
        self.id_bidder = id_bidder
        self.bid_price = bid_price
        self.budget = budget
        self.spent = 0
        self.target_queries = []
        
    def add_target_query(self,query_id):
        if query_id not in self.target_queries:
            self.target_queries.append(query_id)
            
    def is_bidder_intrested_in_query(self, query):
        return query in self.target_queries
    
    def is_bidding_active(self):
        return (self.budget>self.spent)
    
    def attribute_query(self):
        self.spent += self.bid_price
        
    def fi_value(self):
        return self.bid_price*(1-math.exp(1-(self.spent/self.budget)))
    
    def __str__(self):
        return "bidder "+self.id_bidder.__str__()+" bidding:"+self.bid_price.__str__()+" spent : "+self.spent.__str__()+"/"+self.budget.__str__()+" : "+self.target_queries.__str__()
    
class bidding_manager:
    def __init__(self, nb_bidders, nb_queries, intrest_per_bidder):
        self.nb_bidders = nb_bidders
        self.intrest_per_bidder = intrest_per_bidder
        self.bidders = [] # list of bidder_objects
        self.nb_queries = nb_queries
        self.available = range(nb_queries)
        
        self.stream_history = []
        
    
    def randomize_the_demande(self):
        for i in range(self.nb_bidders):
            price = random.randrange(18)+2
            stock = random.randrange(27)+3
            bid = bidder(i,price,stock*price)
            for j in range(self.intrest_per_bidder):
                bid.add_target_query(random.randrange(self.nb_queries))
            print(bid.__str__())
            self.bidders.append(bid)
        
    
    def select_best_bid(self, call):
        possible_values = []
        possible_bidders = []
        
        for bid in self.bidders:
            if ( bid.is_bidding_active() and bid.is_bidder_intrested_in_query(call)):
                possible_values.append(bid.fi_value())
                possible_bidders.append(bid)
        
        #choose the bid with max values
        if(len(possible_values) > 0):
            idx = np.argmax(possible_values)
            print("selected bidder id:%d"%possible_bidders[idx].id_bidder)
            possible_bidders[idx].attribute_query()
            print(possible_bidders[idx].__str__())
        else:
            print("bidders all inactive")
        
        
    
    def simulate_random_queries(self, stream_size):
        for i in range(stream_size):  
            call = random.randrange(self.nb_queries)
            print(" the query for %d:"%call)
            self.stream_history.append(call)
            self.select_best_bid(call)
            
    def get_total_gains(self):
        total = 0
        for bid in self.bidders:
            total += bid.spent
            
        print("TOTAL GAINS IS %d"%total)
        return total

# %% [markdown]
# _You can use this cell to write your discussion of the results_

# %%
mn = bidding_manager(10,10,3)
mn.randomize_the_demande()

mn.simulate_random_queries(150)
mn.get_total_gains()
# Out:
# bidder 0 bidding:13 spent : 0/78 : [7, 4, 5]
# bidder 1 bidding:3 spent : 0/21 : [2, 0, 3]
# bidder 2 bidding:9 spent : 0/126 : [8, 9, 0]
# bidder 3 bidding:6 spent : 0/84 : [4, 2]
# bidder 4 bidding:16 spent : 0/304 : [0, 6]
# bidder 5 bidding:14 spent : 0/308 : [5, 0, 8]
# bidder 6 bidding:4 spent : 0/84 : [8, 1]
# bidder 7 bidding:11 spent : 0/66 : [5, 8, 4]
# bidder 8 bidding:15 spent : 0/120 : [2, 3, 4]
# bidder 9 bidding:12 spent : 0/108 : [9, 5, 3]
#  the query for 7:
# selected bidder id:0
# bidder 0 bidding:13 spent : 13/78 : [7, 4, 5]
#  the query for 5:
# selected bidder id:0
# bidder 0 bidding:13 spent : 26/78 : [7, 4, 5]
#  the query for 1:
# selected bidder id:6
# bidder 6 bidding:4 spent : 4/84 : [8, 1]
#  the query for 0:
# selected bidder id:1
# bidder 1 bidding:3 spent : 3/21 : [2, 0, 3]
#  the query for 2:
# selected bidder id:1
# bidder 1 bidding:3 spent : 6/21 : [2, 0, 3]
#  the query for 0:
# selected bidder id:1
# bidder 1 bidding:3 spent : 9/21 : [2, 0, 3]
#  the query for 1:
# selected bidder id:6
# bidder 6 bidding:4 spent : 8/84 : [8, 1]
#  the query for 9:
# selected bidder id:2
# bidder 2 bidding:9 spent : 9/126 : [8, 9, 0]
#  the query for 1:
# selected bidder id:6
# bidder 6 bidding:4 spent : 12/84 : [8, 1]
#  the query for 2:
# selected bidder id:1
# bidder 1 bidding:3 spent : 12/21 : [2, 0, 3]
#  the query for 6:
# selected bidder id:4
# bidder 4 bidding:16 spent : 16/304 : [0, 6]
#  the query for 1:
# selected bidder id:6
# bidder 6 bidding:4 spent : 16/84 : [8, 1]
#  the query for 1:
# selected bidder id:6
# bidder 6 bidding:4 spent : 20/84 : [8, 1]
#  the query for 0:
# selected bidder id:1
# bidder 1 bidding:3 spent : 15/21 : [2, 0, 3]
#  the query for 2:
# selected bidder id:1
# bidder 1 bidding:3 spent : 18/21 : [2, 0, 3]
#  the query for 4:
# selected bidder id:3
# bidder 3 bidding:6 spent : 6/84 : [4, 2]
#  the query for 6:
# selected bidder id:4
# bidder 4 bidding:16 spent : 32/304 : [0, 6]
#  the query for 5:
# selected bidder id:0
# bidder 0 bidding:13 spent : 39/78 : [7, 4, 5]
#  the query for 6:
# selected bidder id:4
# bidder 4 bidding:16 spent : 48/304 : [0, 6]
#  the query for 7:
# selected bidder id:0
# bidder 0 bidding:13 spent : 52/78 : [7, 4, 5]
#  the query for 6:
# selected bidder id:4
# bidder 4 bidding:16 spent : 64/304 : [0, 6]
#  the query for 5:
# selected bidder id:0
# bidder 0 bidding:13 spent : 65/78 : [7, 4, 5]
#  the query for 5:
# selected bidder id:0
# bidder 0 bidding:13 spent : 78/78 : [7, 4, 5]
#  the query for 8:
# selected bidder id:6
# bidder 6 bidding:4 spent : 24/84 : [8, 1]
#  the query for 9:
# selected bidder id:2
# bidder 2 bidding:9 spent : 18/126 : [8, 9, 0]
#  the query for 5:
# selected bidder id:7
# bidder 7 bidding:11 spent : 11/66 : [5, 8, 4]
#  the query for 6:
# selected bidder id:4
# bidder 4 bidding:16 spent : 80/304 : [0, 6]
#  the query for 1:
# selected bidder id:6
# bidder 6 bidding:4 spent : 28/84 : [8, 1]
#  the query for 5:
# selected bidder id:7
# bidder 7 bidding:11 spent : 22/66 : [5, 8, 4]
#  the query for 1:
# selected bidder id:6
# bidder 6 bidding:4 spent : 32/84 : [8, 1]
#  the query for 0:
# selected bidder id:1
# bidder 1 bidding:3 spent : 21/21 : [2, 0, 3]
#  the query for 5:
# selected bidder id:7
# bidder 7 bidding:11 spent : 33/66 : [5, 8, 4]
#  the query for 3:
# selected bidder id:9
# bidder 9 bidding:12 spent : 12/108 : [9, 5, 3]
#  the query for 3:
# selected bidder id:9
# bidder 9 bidding:12 spent : 24/108 : [9, 5, 3]
#  the query for 2:
# selected bidder id:3
# bidder 3 bidding:6 spent : 12/84 : [4, 2]
#  the query for 1:
# selected bidder id:6
# bidder 6 bidding:4 spent : 36/84 : [8, 1]
#  the query for 6:
# selected bidder id:4
# bidder 4 bidding:16 spent : 96/304 : [0, 6]
#  the query for 0:
# selected bidder id:2
# bidder 2 bidding:9 spent : 27/126 : [8, 9, 0]
#  the query for 7:
# bidders all inactive
#  the query for 6:
# selected bidder id:4
# bidder 4 bidding:16 spent : 112/304 : [0, 6]
#  the query for 3:
# selected bidder id:9
# bidder 9 bidding:12 spent : 36/108 : [9, 5, 3]
#  the query for 6:
# selected bidder id:4
# bidder 4 bidding:16 spent : 128/304 : [0, 6]
#  the query for 2:
# selected bidder id:3
# bidder 3 bidding:6 spent : 18/84 : [4, 2]
#  the query for 3:
# selected bidder id:9
# bidder 9 bidding:12 spent : 48/108 : [9, 5, 3]
#  the query for 4:
# selected bidder id:7
# bidder 7 bidding:11 spent : 44/66 : [5, 8, 4]
#  the query for 3:
# selected bidder id:9
# bidder 9 bidding:12 spent : 60/108 : [9, 5, 3]
#  the query for 5:
# selected bidder id:7
# bidder 7 bidding:11 spent : 55/66 : [5, 8, 4]
#  the query for 7:
# bidders all inactive
#  the query for 0:
# selected bidder id:2
# bidder 2 bidding:9 spent : 36/126 : [8, 9, 0]
#  the query for 8:
# selected bidder id:7
# bidder 7 bidding:11 spent : 66/66 : [5, 8, 4]
#  the query for 0:
# selected bidder id:2
# bidder 2 bidding:9 spent : 45/126 : [8, 9, 0]
#  the query for 1:
# selected bidder id:6
# bidder 6 bidding:4 spent : 40/84 : [8, 1]
#  the query for 9:
# selected bidder id:9
# bidder 9 bidding:12 spent : 72/108 : [9, 5, 3]
#  the query for 4:
# selected bidder id:3
# bidder 3 bidding:6 spent : 24/84 : [4, 2]
#  the query for 5:
# selected bidder id:9
# bidder 9 bidding:12 spent : 84/108 : [9, 5, 3]
#  the query for 4:
# selected bidder id:3
# bidder 3 bidding:6 spent : 30/84 : [4, 2]
#  the query for 9:
# selected bidder id:9
# bidder 9 bidding:12 spent : 96/108 : [9, 5, 3]
#  the query for 4:
# selected bidder id:3
# bidder 3 bidding:6 spent : 36/84 : [4, 2]
#  the query for 3:
# selected bidder id:9
# bidder 9 bidding:12 spent : 108/108 : [9, 5, 3]
#  the query for 4:
# selected bidder id:3
# bidder 3 bidding:6 spent : 42/84 : [4, 2]
#  the query for 5:
# selected bidder id:5
# bidder 5 bidding:14 spent : 14/308 : [5, 0, 8]
#  the query for 5:
# selected bidder id:5
# bidder 5 bidding:14 spent : 28/308 : [5, 0, 8]
#  the query for 2:
# selected bidder id:3
# bidder 3 bidding:6 spent : 48/84 : [4, 2]
#  the query for 4:
# selected bidder id:3
# bidder 3 bidding:6 spent : 54/84 : [4, 2]
#  the query for 2:
# selected bidder id:3
# bidder 3 bidding:6 spent : 60/84 : [4, 2]
#  the query for 9:
# selected bidder id:2
# bidder 2 bidding:9 spent : 54/126 : [8, 9, 0]
#  the query for 6:
# selected bidder id:4
# bidder 4 bidding:16 spent : 144/304 : [0, 6]
#  the query for 6:
# selected bidder id:4
# bidder 4 bidding:16 spent : 160/304 : [0, 6]
#  the query for 5:
# selected bidder id:5
# bidder 5 bidding:14 spent : 42/308 : [5, 0, 8]
#  the query for 8:
# selected bidder id:6
# bidder 6 bidding:4 spent : 44/84 : [8, 1]
#  the query for 9:
# selected bidder id:2
# bidder 2 bidding:9 spent : 63/126 : [8, 9, 0]
#  the query for 1:
# selected bidder id:6
# bidder 6 bidding:4 spent : 48/84 : [8, 1]
#  the query for 2:
# selected bidder id:3
# bidder 3 bidding:6 spent : 66/84 : [4, 2]
#  the query for 7:
# bidders all inactive
#  the query for 8:
# selected bidder id:6
# bidder 6 bidding:4 spent : 52/84 : [8, 1]
#  the query for 4:
# selected bidder id:3
# bidder 3 bidding:6 spent : 72/84 : [4, 2]
#  the query for 3:
# selected bidder id:8
# bidder 8 bidding:15 spent : 15/120 : [2, 3, 4]
#  the query for 3:
# selected bidder id:8
# bidder 8 bidding:15 spent : 30/120 : [2, 3, 4]
#  the query for 5:
# selected bidder id:5
# bidder 5 bidding:14 spent : 56/308 : [5, 0, 8]
#  the query for 1:
# selected bidder id:6
# bidder 6 bidding:4 spent : 56/84 : [8, 1]
#  the query for 4:
# selected bidder id:3
# bidder 3 bidding:6 spent : 78/84 : [4, 2]
#  the query for 7:
# bidders all inactive
#  the query for 7:
# bidders all inactive
#  the query for 8:
# selected bidder id:6
# bidder 6 bidding:4 spent : 60/84 : [8, 1]
#  the query for 8:
# selected bidder id:6
# bidder 6 bidding:4 spent : 64/84 : [8, 1]
#  the query for 2:
# selected bidder id:3
# bidder 3 bidding:6 spent : 84/84 : [4, 2]
#  the query for 2:
# selected bidder id:8
# bidder 8 bidding:15 spent : 45/120 : [2, 3, 4]
#  the query for 0:
# selected bidder id:2
# bidder 2 bidding:9 spent : 72/126 : [8, 9, 0]
#  the query for 0:
# selected bidder id:2
# bidder 2 bidding:9 spent : 81/126 : [8, 9, 0]
#  the query for 7:
# bidders all inactive
#  the query for 9:
# selected bidder id:2
# bidder 2 bidding:9 spent : 90/126 : [8, 9, 0]
#  the query for 5:
# selected bidder id:5
# bidder 5 bidding:14 spent : 70/308 : [5, 0, 8]
#  the query for 8:
# selected bidder id:6
# bidder 6 bidding:4 spent : 68/84 : [8, 1]
#  the query for 4:
# selected bidder id:8
# bidder 8 bidding:15 spent : 60/120 : [2, 3, 4]
#  the query for 4:
# selected bidder id:8
# bidder 8 bidding:15 spent : 75/120 : [2, 3, 4]
#  the query for 6:
# selected bidder id:4
# bidder 4 bidding:16 spent : 176/304 : [0, 6]
#  the query for 3:
# selected bidder id:8
# bidder 8 bidding:15 spent : 90/120 : [2, 3, 4]
#  the query for 6:
# selected bidder id:4
# bidder 4 bidding:16 spent : 192/304 : [0, 6]
#  the query for 6:
# selected bidder id:4
# bidder 4 bidding:16 spent : 208/304 : [0, 6]
#  the query for 9:
# selected bidder id:2
# bidder 2 bidding:9 spent : 99/126 : [8, 9, 0]
#  the query for 2:
# selected bidder id:8
# bidder 8 bidding:15 spent : 105/120 : [2, 3, 4]
#  the query for 2:
# selected bidder id:8
# bidder 8 bidding:15 spent : 120/120 : [2, 3, 4]
#  the query for 0:
# selected bidder id:2
# bidder 2 bidding:9 spent : 108/126 : [8, 9, 0]
#  the query for 3:
# bidders all inactive
#  the query for 3:
# bidders all inactive
#  the query for 3:
# bidders all inactive
#  the query for 5:
# selected bidder id:5
# bidder 5 bidding:14 spent : 84/308 : [5, 0, 8]
#  the query for 8:
# selected bidder id:6
# bidder 6 bidding:4 spent : 72/84 : [8, 1]
#  the query for 9:
# selected bidder id:2
# bidder 2 bidding:9 spent : 117/126 : [8, 9, 0]
#  the query for 4:
# bidders all inactive
#  the query for 2:
# bidders all inactive
#  the query for 0:
# selected bidder id:2
# bidder 2 bidding:9 spent : 126/126 : [8, 9, 0]
#  the query for 4:
# bidders all inactive
#  the query for 2:
# bidders all inactive
#  the query for 2:
# bidders all inactive
#  the query for 4:
# bidders all inactive
#  the query for 1:
# selected bidder id:6
# bidder 6 bidding:4 spent : 76/84 : [8, 1]
#  the query for 2:
# bidders all inactive
#  the query for 3:
# bidders all inactive
#  the query for 1:
# selected bidder id:6
# bidder 6 bidding:4 spent : 80/84 : [8, 1]
#  the query for 3:
# bidders all inactive
#  the query for 1:
# selected bidder id:6
# bidder 6 bidding:4 spent : 84/84 : [8, 1]
#  the query for 8:
# selected bidder id:5
# bidder 5 bidding:14 spent : 98/308 : [5, 0, 8]
#  the query for 9:
# bidders all inactive
#  the query for 2:
# bidders all inactive
#  the query for 3:
# bidders all inactive
#  the query for 8:
# selected bidder id:5
# bidder 5 bidding:14 spent : 112/308 : [5, 0, 8]
#  the query for 7:
# bidders all inactive
#  the query for 5:
# selected bidder id:5
# bidder 5 bidding:14 spent : 126/308 : [5, 0, 8]
#  the query for 5:
# selected bidder id:5
# bidder 5 bidding:14 spent : 140/308 : [5, 0, 8]
#  the query for 8:
# selected bidder id:5
# bidder 5 bidding:14 spent : 154/308 : [5, 0, 8]
#  the query for 4:
# bidders all inactive
#  the query for 8:
# selected bidder id:5
# bidder 5 bidding:14 spent : 168/308 : [5, 0, 8]
#  the query for 4:
# bidders all inactive
#  the query for 7:
# bidders all inactive
#  the query for 1:
# bidders all inactive
#  the query for 2:
# bidders all inactive
#  the query for 3:
# bidders all inactive
#  the query for 9:
# bidders all inactive
#  the query for 9:
# bidders all inactive
#  the query for 7:
# bidders all inactive
#  the query for 0:
# selected bidder id:4
# bidder 4 bidding:16 spent : 224/304 : [0, 6]
#  the query for 7:
# bidders all inactive
#  the query for 9:
# bidders all inactive
#  the query for 4:
# bidders all inactive
#  the query for 3:
# bidders all inactive
#  the query for 4:
# bidders all inactive
#  the query for 9:
# bidders all inactive
#  the query for 8:
# selected bidder id:5
# bidder 5 bidding:14 spent : 182/308 : [5, 0, 8]
#  the query for 8:
# selected bidder id:5
# bidder 5 bidding:14 spent : 196/308 : [5, 0, 8]
# TOTAL GAINS IS 1107

# %%
from statistics import mean,median

try_ = 10
data = []

for i in range(try_):
    mn = bidding_manager(10,10,3)
    mn.randomize_the_demande()

    mn.simulate_random_queries(150)
    data.append(mn.get_total_gains())
    

print(" average gains is : %d"%mean(data))
print(" min gains is : %d"%min(data))   
print(" max gains is : %d"%max(data))
# Out:
# bidder 0 bidding:19 spent : 0/76 : [1, 5, 0]
# bidder 1 bidding:6 spent : 0/174 : [7, 4]
# bidder 2 bidding:4 spent : 0/92 : [7, 5]
# bidder 3 bidding:13 spent : 0/260 : [7, 3, 5]
# bidder 4 bidding:15 spent : 0/150 : [4, 5]
# bidder 5 bidding:8 spent : 0/176 : [5, 9, 2]
# bidder 6 bidding:9 spent : 0/99 : [0, 2, 5]
# bidder 7 bidding:13 spent : 0/104 : [9, 8, 5]
# bidder 8 bidding:8 spent : 0/40 : [9, 7, 8]
# bidder 9 bidding:4 spent : 0/16 : [8, 0, 5]
#  the query for 6:
# bidders all inactive
#  the query for 7:
# selected bidder id:2
# bidder 2 bidding:4 spent : 4/92 : [7, 5]
#  the query for 1:
# selected bidder id:0
# bidder 0 bidding:19 spent : 19/76 : [1, 5, 0]
#  the query for 3:
# selected bidder id:3
# bidder 3 bidding:13 spent : 13/260 : [7, 3, 5]
#  the query for 7:
# selected bidder id:2
# bidder 2 bidding:4 spent : 8/92 : [7, 5]
#  the query for 6:
# bidders all inactive
#  the query for 9:
# selected bidder id:5
# bidder 5 bidding:8 spent : 8/176 : [5, 9, 2]
#  the query for 1:
# selected bidder id:0
# bidder 0 bidding:19 spent : 38/76 : [1, 5, 0]
#  the query for 5:
# selected bidder id:2
# bidder 2 bidding:4 spent : 12/92 : [7, 5]
#  the query for 0:
# selected bidder id:9
# bidder 9 bidding:4 spent : 4/16 : [8, 0, 5]
#  the query for 6:
# bidders all inactive
#  the query for 9:
# selected bidder id:5
# bidder 5 bidding:8 spent : 16/176 : [5, 9, 2]
#  the query for 9:
# selected bidder id:5
# bidder 5 bidding:8 spent : 24/176 : [5, 9, 2]
#  the query for 6:
# bidders all inactive
#  the query for 4:
# selected bidder id:1
# bidder 1 bidding:6 spent : 6/174 : [7, 4]
#  the query for 2:
# selected bidder id:5
# bidder 5 bidding:8 spent : 32/176 : [5, 9, 2]
#  the query for 2:
# selected bidder id:5
# bidder 5 bidding:8 spent : 40/176 : [5, 9, 2]
#  the query for 8:
# selected bidder id:9
# bidder 9 bidding:4 spent : 8/16 : [8, 0, 5]
#  the query for 6:
# bidders all inactive
#  the query for 4:
# selected bidder id:1
# bidder 1 bidding:6 spent : 12/174 : [7, 4]
#  the query for 0:
# selected bidder id:9
# bidder 9 bidding:4 spent : 12/16 : [8, 0, 5]
#  the query for 4:
# selected bidder id:1
# bidder 1 bidding:6 spent : 18/174 : [7, 4]
#  the query for 8:
# selected bidder id:9
# bidder 9 bidding:4 spent : 16/16 : [8, 0, 5]
#  the query for 5:
# selected bidder id:2
# bidder 2 bidding:4 spent : 16/92 : [7, 5]
#  the query for 3:
# selected bidder id:3
# bidder 3 bidding:13 spent : 26/260 : [7, 3, 5]
#  the query for 5:
# selected bidder id:2
# bidder 2 bidding:4 spent : 20/92 : [7, 5]
#  the query for 6:
# bidders all inactive
#  the query for 7:
# selected bidder id:2
# bidder 2 bidding:4 spent : 24/92 : [7, 5]
#  the query for 7:
# selected bidder id:2
# bidder 2 bidding:4 spent : 28/92 : [7, 5]
#  the query for 9:
# selected bidder id:5
# bidder 5 bidding:8 spent : 48/176 : [5, 9, 2]
#  the query for 8:
# selected bidder id:8
# bidder 8 bidding:8 spent : 8/40 : [9, 7, 8]
#  the query for 6:
# bidders all inactive
#  the query for 0:
# selected bidder id:0
# bidder 0 bidding:19 spent : 57/76 : [1, 5, 0]
#  the query for 3:
# selected bidder id:3
# bidder 3 bidding:13 spent : 39/260 : [7, 3, 5]
#  the query for 6:
# bidders all inactive
#  the query for 5:
# selected bidder id:2
# bidder 2 bidding:4 spent : 32/92 : [7, 5]
#  the query for 7:
# selected bidder id:2
# bidder 2 bidding:4 spent : 36/92 : [7, 5]
#  the query for 1:
# selected bidder id:0
# bidder 0 bidding:19 spent : 76/76 : [1, 5, 0]
#  the query for 5:
# selected bidder id:2
# bidder 2 bidding:4 spent : 40/92 : [7, 5]
#  the query for 3:
# selected bidder id:3
# bidder 3 bidding:13 spent : 52/260 : [7, 3, 5]
#  the query for 3:
# selected bidder id:3
# bidder 3 bidding:13 spent : 65/260 : [7, 3, 5]
#  the query for 0:
# selected bidder id:6
# bidder 6 bidding:9 spent : 9/99 : [0, 2, 5]
#  the query for 7:
# selected bidder id:2
# bidder 2 bidding:4 spent : 44/92 : [7, 5]
#  the query for 4:
# selected bidder id:1
# bidder 1 bidding:6 spent : 24/174 : [7, 4]
#  the query for 8:
# selected bidder id:8
# bidder 8 bidding:8 spent : 16/40 : [9, 7, 8]
#  the query for 9:
# selected bidder id:8
# bidder 8 bidding:8 spent : 24/40 : [9, 7, 8]
#  the query for 7:
# selected bidder id:2
# bidder 2 bidding:4 spent : 48/92 : [7, 5]
#  the query for 6:
# bidders all inactive
#  the query for 5:
# selected bidder id:2
# bidder 2 bidding:4 spent : 52/92 : [7, 5]
#  the query for 2:
# selected bidder id:5
# bidder 5 bidding:8 spent : 56/176 : [5, 9, 2]
#  the query for 7:
# selected bidder id:2
# bidder 2 bidding:4 spent : 56/92 : [7, 5]
#  the query for 0:
# selected bidder id:6
# bidder 6 bidding:9 spent : 18/99 : [0, 2, 5]
#  the query for 3:
# selected bidder id:3
# bidder 3 bidding:13 spent : 78/260 : [7, 3, 5]
#  the query for 4:
# selected bidder id:1
# bidder 1 bidding:6 spent : 30/174 : [7, 4]
#  the query for 1:
# bidders all inactive
#  the query for 8:
# selected bidder id:8
# bidder 8 bidding:8 spent : 32/40 : [9, 7, 8]
#  the query for 0:
# selected bidder id:6
# bidder 6 bidding:9 spent : 27/99 : [0, 2, 5]
#  the query for 9:
# selected bidder id:8
# bidder 8 bidding:8 spent : 40/40 : [9, 7, 8]
#  the query for 8:
# selected bidder id:7
# bidder 7 bidding:13 spent : 13/104 : [9, 8, 5]
#  the query for 6:
# bidders all inactive
#  the query for 5:
# selected bidder id:2
# bidder 2 bidding:4 spent : 60/92 : [7, 5]
#  the query for 3:
# selected bidder id:3
# bidder 3 bidding:13 spent : 91/260 : [7, 3, 5]
#  the query for 9:
# selected bidder id:5
# bidder 5 bidding:8 spent : 64/176 : [5, 9, 2]
#  the query for 0:
# selected bidder id:6
# bidder 6 bidding:9 spent : 36/99 : [0, 2, 5]
#  the query for 0:
# selected bidder id:6
# bidder 6 bidding:9 spent : 45/99 : [0, 2, 5]
#  the query for 1:
# bidders all inactive
#  the query for 6:
# bidders all inactive
#  the query for 4:
# selected bidder id:1
# bidder 1 bidding:6 spent : 36/174 : [7, 4]
#  the query for 6:
# bidders all inactive
#  the query for 8:
# selected bidder id:7
# bidder 7 bidding:13 spent : 26/104 : [9, 8, 5]
#  the query for 9:
# selected bidder id:5
# bidder 5 bidding:8 spent : 72/176 : [5, 9, 2]
#  the query for 1:
# bidders all inactive
#  the query for 6:
# bidders all inactive
#  the query for 2:
# selected bidder id:5
# bidder 5 bidding:8 spent : 80/176 : [5, 9, 2]
#  the query for 4:
# selected bidder id:1
# bidder 1 bidding:6 spent : 42/174 : [7, 4]
#  the query for 6:
# bidders all inactive
#  the query for 8:
# selected bidder id:7
# bidder 7 bidding:13 spent : 39/104 : [9, 8, 5]
#  the query for 7:
# selected bidder id:2
# bidder 2 bidding:4 spent : 64/92 : [7, 5]
#  the query for 4:
# selected bidder id:1
# bidder 1 bidding:6 spent : 48/174 : [7, 4]
#  the query for 4:
# selected bidder id:1
# bidder 1 bidding:6 spent : 54/174 : [7, 4]
#  the query for 1:
# bidders all inactive
#  the query for 1:
# bidders all inactive
#  the query for 1:
# bidders all inactive
#  the query for 6:
# bidders all inactive
#  the query for 8:
# selected bidder id:7
# bidder 7 bidding:13 spent : 52/104 : [9, 8, 5]
#  the query for 2:
# selected bidder id:5
# bidder 5 bidding:8 spent : 88/176 : [5, 9, 2]
#  the query for 9:
# selected bidder id:5
# bidder 5 bidding:8 spent : 96/176 : [5, 9, 2]
#  the query for 9:
# selected bidder id:5
# bidder 5 bidding:8 spent : 104/176 : [5, 9, 2]
#  the query for 7:
# selected bidder id:2
# bidder 2 bidding:4 spent : 68/92 : [7, 5]
#  the query for 3:
# selected bidder id:3
# bidder 3 bidding:13 spent : 104/260 : [7, 3, 5]
#  the query for 4:
# selected bidder id:1
# bidder 1 bidding:6 spent : 60/174 : [7, 4]
#  the query for 5:
# selected bidder id:2
# bidder 2 bidding:4 spent : 72/92 : [7, 5]
#  the query for 7:
# selected bidder id:2
# bidder 2 bidding:4 spent : 76/92 : [7, 5]
#  the query for 0:
# selected bidder id:6
# bidder 6 bidding:9 spent : 54/99 : [0, 2, 5]
#  the query for 8:
# selected bidder id:7
# bidder 7 bidding:13 spent : 65/104 : [9, 8, 5]
#  the query for 8:
# selected bidder id:7
# bidder 7 bidding:13 spent : 78/104 : [9, 8, 5]
#  the query for 7:
# selected bidder id:2
# bidder 2 bidding:4 spent : 80/92 : [7, 5]
#  the query for 8:
# selected bidder id:7
# bidder 7 bidding:13 spent : 91/104 : [9, 8, 5]
#  the query for 2:
# selected bidder id:5
# bidder 5 bidding:8 spent : 112/176 : [5, 9, 2]
#  the query for 0:
# selected bidder id:6
# bidder 6 bidding:9 spent : 63/99 : [0, 2, 5]
#  the query for 5:
# selected bidder id:2
# bidder 2 bidding:4 spent : 84/92 : [7, 5]
#  the query for 8:
# selected bidder id:7
# bidder 7 bidding:13 spent : 104/104 : [9, 8, 5]
#  the query for 8:
# bidders all inactive
#  the query for 9:
# selected bidder id:5
# bidder 5 bidding:8 spent : 120/176 : [5, 9, 2]
#  the query for 9:
# selected bidder id:5
# bidder 5 bidding:8 spent : 128/176 : [5, 9, 2]
#  the query for 6:
# bidders all inactive
#  the query for 0:
# selected bidder id:6
# bidder 6 bidding:9 spent : 72/99 : [0, 2, 5]
#  the query for 8:
# bidders all inactive
#  the query for 5:
# selected bidder id:2
# bidder 2 bidding:4 spent : 88/92 : [7, 5]
#  the query for 9:
# selected bidder id:5
# bidder 5 bidding:8 spent : 136/176 : [5, 9, 2]
#  the query for 3:
# selected bidder id:3
# bidder 3 bidding:13 spent : 117/260 : [7, 3, 5]
#  the query for 9:
# selected bidder id:5
# bidder 5 bidding:8 spent : 144/176 : [5, 9, 2]
#  the query for 0:
# selected bidder id:6
# bidder 6 bidding:9 spent : 81/99 : [0, 2, 5]
#  the query for 5:
# selected bidder id:2
# bidder 2 bidding:4 spent : 92/92 : [7, 5]
#  the query for 2:
# selected bidder id:5
# bidder 5 bidding:8 spent : 152/176 : [5, 9, 2]
#  the query for 6:
# bidders all inactive
#  the query for 1:
# bidders all inactive
#  the query for 1:
# bidders all inactive
#  the query for 5:
# selected bidder id:5
# bidder 5 bidding:8 spent : 160/176 : [5, 9, 2]
#  the query for 3:
# selected bidder id:3
# bidder 3 bidding:13 spent : 130/260 : [7, 3, 5]
#  the query for 4:
# selected bidder id:1
# bidder 1 bidding:6 spent : 66/174 : [7, 4]
#  the query for 9:
# selected bidder id:5
# bidder 5 bidding:8 spent : 168/176 : [5, 9, 2]
#  the query for 1:
# bidders all inactive
#  the query for 1:
# bidders all inactive
#  the query for 8:
# bidders all inactive
#  the query for 7:
# selected bidder id:1
# bidder 1 bidding:6 spent : 72/174 : [7, 4]
#  the query for 9:
# selected bidder id:5
# bidder 5 bidding:8 spent : 176/176 : [5, 9, 2]
#  the query for 5:
# selected bidder id:6
# bidder 6 bidding:9 spent : 90/99 : [0, 2, 5]
#  the query for 6:
# bidders all inactive
#  the query for 5:
# selected bidder id:6
# bidder 6 bidding:9 spent : 99/99 : [0, 2, 5]
#  the query for 4:
# selected bidder id:1
# bidder 1 bidding:6 spent : 78/174 : [7, 4]
#  the query for 4:
# selected bidder id:1
# bidder 1 bidding:6 spent : 84/174 : [7, 4]
#  the query for 7:
# selected bidder id:1
# bidder 1 bidding:6 spent : 90/174 : [7, 4]
#  the query for 5:
# selected bidder id:3
# bidder 3 bidding:13 spent : 143/260 : [7, 3, 5]
#  the query for 8:
# bidders all inactive
#  the query for 9:
# bidders all inactive
#  the query for 4:
# selected bidder id:1
# bidder 1 bidding:6 spent : 96/174 : [7, 4]
#  the query for 5:
# selected bidder id:3
# bidder 3 bidding:13 spent : 156/260 : [7, 3, 5]
#  the query for 7:
# selected bidder id:1
# bidder 1 bidding:6 spent : 102/174 : [7, 4]
#  the query for 3:
# selected bidder id:3
# bidder 3 bidding:13 spent : 169/260 : [7, 3, 5]
#  the query for 3:
# selected bidder id:3
# bidder 3 bidding:13 spent : 182/260 : [7, 3, 5]
#  the query for 5:
# selected bidder id:3
# bidder 3 bidding:13 spent : 195/260 : [7, 3, 5]
#  the query for 2:
# bidders all inactive
#  the query for 7:
# selected bidder id:1
# bidder 1 bidding:6 spent : 108/174 : [7, 4]
#  the query for 8:
# bidders all inactive
#  the query for 5:
# selected bidder id:3
# bidder 3 bidding:13 spent : 208/260 : [7, 3, 5]
#  the query for 8:
# bidders all inactive
#  the query for 5:
# selected bidder id:3
# bidder 3 bidding:13 spent : 221/260 : [7, 3, 5]
#  the query for 8:
# bidders all inactive
#  the query for 8:
# bidders all inactive
# TOTAL GAINS IS 932
# bidder 0 bidding:5 spent : 0/75 : [0, 6, 4]
# bidder 1 bidding:19 spent : 0/342 : [6, 8, 4]
# bidder 2 bidding:12 spent : 0/312 : [4, 6, 2]
# bidder 3 bidding:12 spent : 0/216 : [2, 8, 6]
# bidder 4 bidding:6 spent : 0/144 : [5, 2, 8]
# bidder 5 bidding:2 spent : 0/10 : [9, 2]
# bidder 6 bidding:16 spent : 0/272 : [2, 0, 1]
# bidder 7 bidding:12 spent : 0/288 : [3, 1]
# bidder 8 bidding:9 spent : 0/126 : [7, 3, 8]
# bidder 9 bidding:5 spent : 0/110 : [3, 4, 2]
#  the query for 3:
# selected bidder id:9
# bidder 9 bidding:5 spent : 5/110 : [3, 4, 2]
#  the query for 7:
# selected bidder id:8
# bidder 8 bidding:9 spent : 9/126 : [7, 3, 8]
#  the query for 9:
# selected bidder id:5
# bidder 5 bidding:2 spent : 2/10 : [9, 2]
#  the query for 9:
# selected bidder id:5
# bidder 5 bidding:2 spent : 4/10 : [9, 2]
#  the query for 1:
# selected bidder id:7
# bidder 7 bidding:12 spent : 12/288 : [3, 1]
#  the query for 9:
# selected bidder id:5
# bidder 5 bidding:2 spent : 6/10 : [9, 2]
#  the query for 4:
# selected bidder id:9
# bidder 9 bidding:5 spent : 10/110 : [3, 4, 2]
#  the query for 3:
# selected bidder id:9
# bidder 9 bidding:5 spent : 15/110 : [3, 4, 2]
#  the query for 9:
# selected bidder id:5
# bidder 5 bidding:2 spent : 8/10 : [9, 2]
#  the query for 3:
# selected bidder id:9
# bidder 9 bidding:5 spent : 20/110 : [3, 4, 2]
#  the query for 0:
# selected bidder id:0
# bidder 0 bidding:5 spent : 5/75 : [0, 6, 4]
#  the query for 7:
# selected bidder id:8
# bidder 8 bidding:9 spent : 18/126 : [7, 3, 8]
#  the query for 8:
# selected bidder id:4
# bidder 4 bidding:6 spent : 6/144 : [5, 2, 8]
#  the query for 4:
# selected bidder id:9
# bidder 9 bidding:5 spent : 25/110 : [3, 4, 2]
#  the query for 1:
# selected bidder id:7
# bidder 7 bidding:12 spent : 24/288 : [3, 1]
#  the query for 0:
# selected bidder id:0
# bidder 0 bidding:5 spent : 10/75 : [0, 6, 4]
#  the query for 7:
# selected bidder id:8
# bidder 8 bidding:9 spent : 27/126 : [7, 3, 8]
#  the query for 8:
# selected bidder id:4
# bidder 4 bidding:6 spent : 12/144 : [5, 2, 8]
#  the query for 3:
# selected bidder id:9
# bidder 9 bidding:5 spent : 30/110 : [3, 4, 2]
#  the query for 6:
# selected bidder id:0
# bidder 0 bidding:5 spent : 15/75 : [0, 6, 4]
#  the query for 8:
# selected bidder id:4
# bidder 4 bidding:6 spent : 18/144 : [5, 2, 8]
#  the query for 7:
# selected bidder id:8
# bidder 8 bidding:9 spent : 36/126 : [7, 3, 8]
#  the query for 9:
# selected bidder id:5
# bidder 5 bidding:2 spent : 10/10 : [9, 2]
#  the query for 5:
# selected bidder id:4
# bidder 4 bidding:6 spent : 24/144 : [5, 2, 8]
#  the query for 2:
# selected bidder id:9
# bidder 9 bidding:5 spent : 35/110 : [3, 4, 2]
#  the query for 1:
# selected bidder id:7
# bidder 7 bidding:12 spent : 36/288 : [3, 1]
#  the query for 4:
# selected bidder id:9
# bidder 9 bidding:5 spent : 40/110 : [3, 4, 2]
#  the query for 8:
# selected bidder id:4
# bidder 4 bidding:6 spent : 30/144 : [5, 2, 8]
#  the query for 2:
# selected bidder id:9
# bidder 9 bidding:5 spent : 45/110 : [3, 4, 2]
#  the query for 9:
# bidders all inactive
#  the query for 2:
# selected bidder id:9
# bidder 9 bidding:5 spent : 50/110 : [3, 4, 2]
#  the query for 9:
# bidders all inactive
#  the query for 2:
# selected bidder id:9
# bidder 9 bidding:5 spent : 55/110 : [3, 4, 2]
#  the query for 0:
# selected bidder id:0
# bidder 0 bidding:5 spent : 20/75 : [0, 6, 4]
#  the query for 1:
# selected bidder id:7
# bidder 7 bidding:12 spent : 48/288 : [3, 1]
#  the query for 2:
# selected bidder id:9
# bidder 9 bidding:5 spent : 60/110 : [3, 4, 2]
#  the query for 4:
# selected bidder id:9
# bidder 9 bidding:5 spent : 65/110 : [3, 4, 2]
#  the query for 4:
# selected bidder id:9
# bidder 9 bidding:5 spent : 70/110 : [3, 4, 2]
#  the query for 0:
# selected bidder id:0
# bidder 0 bidding:5 spent : 25/75 : [0, 6, 4]
#  the query for 5:
# selected bidder id:4
# bidder 4 bidding:6 spent : 36/144 : [5, 2, 8]
#  the query for 6:
# selected bidder id:0
# bidder 0 bidding:5 spent : 30/75 : [0, 6, 4]
#  the query for 5:
# selected bidder id:4
# bidder 4 bidding:6 spent : 42/144 : [5, 2, 8]
#  the query for 2:
# selected bidder id:9
# bidder 9 bidding:5 spent : 75/110 : [3, 4, 2]
#  the query for 9:
# bidders all inactive
#  the query for 0:
# selected bidder id:0
# bidder 0 bidding:5 spent : 35/75 : [0, 6, 4]
#  the query for 6:
# selected bidder id:0
# bidder 0 bidding:5 spent : 40/75 : [0, 6, 4]
#  the query for 8:
# selected bidder id:4
# bidder 4 bidding:6 spent : 48/144 : [5, 2, 8]
#  the query for 2:
# selected bidder id:9
# bidder 9 bidding:5 spent : 80/110 : [3, 4, 2]
#  the query for 1:
# selected bidder id:7
# bidder 7 bidding:12 spent : 60/288 : [3, 1]
#  the query for 1:
# selected bidder id:7
# bidder 7 bidding:12 spent : 72/288 : [3, 1]
#  the query for 6:
# selected bidder id:0
# bidder 0 bidding:5 spent : 45/75 : [0, 6, 4]
#  the query for 7:
# selected bidder id:8
# bidder 8 bidding:9 spent : 45/126 : [7, 3, 8]
#  the query for 3:
# selected bidder id:9
# bidder 9 bidding:5 spent : 85/110 : [3, 4, 2]
#  the query for 4:
# selected bidder id:9
# bidder 9 bidding:5 spent : 90/110 : [3, 4, 2]
#  the query for 2:
# selected bidder id:9
# bidder 9 bidding:5 spent : 95/110 : [3, 4, 2]
#  the query for 8:
# selected bidder id:4
# bidder 4 bidding:6 spent : 54/144 : [5, 2, 8]
#  the query for 6:
# selected bidder id:0
# bidder 0 bidding:5 spent : 50/75 : [0, 6, 4]
#  the query for 7:
# selected bidder id:8
# bidder 8 bidding:9 spent : 54/126 : [7, 3, 8]
#  the query for 3:
# selected bidder id:9
# bidder 9 bidding:5 spent : 100/110 : [3, 4, 2]
#  the query for 8:
# selected bidder id:4
# bidder 4 bidding:6 spent : 60/144 : [5, 2, 8]
#  the query for 3:
# selected bidder id:9
# bidder 9 bidding:5 spent : 105/110 : [3, 4, 2]
#  the query for 6:
# selected bidder id:0
# bidder 0 bidding:5 spent : 55/75 : [0, 6, 4]
#  the query for 5:
# selected bidder id:4
# bidder 4 bidding:6 spent : 66/144 : [5, 2, 8]
#  the query for 2:
# selected bidder id:9
# bidder 9 bidding:5 spent : 110/110 : [3, 4, 2]
#  the query for 8:
# selected bidder id:4
# bidder 4 bidding:6 spent : 72/144 : [5, 2, 8]
#  the query for 2:
# selected bidder id:4
# bidder 4 bidding:6 spent : 78/144 : [5, 2, 8]
#  the query for 9:
# bidders all inactive
#  the query for 4:
# selected bidder id:0
# bidder 0 bidding:5 spent : 60/75 : [0, 6, 4]
#  the query for 5:
# selected bidder id:4
# bidder 4 bidding:6 spent : 84/144 : [5, 2, 8]
#  the query for 9:
# bidders all inactive
#  the query for 7:
# selected bidder id:8
# bidder 8 bidding:9 spent : 63/126 : [7, 3, 8]
#  the query for 1:
# selected bidder id:7
# bidder 7 bidding:12 spent : 84/288 : [3, 1]
#  the query for 8:
# selected bidder id:4
# bidder 4 bidding:6 spent : 90/144 : [5, 2, 8]
#  the query for 4:
# selected bidder id:0
# bidder 0 bidding:5 spent : 65/75 : [0, 6, 4]
#  the query for 6:
# selected bidder id:0
# bidder 0 bidding:5 spent : 70/75 : [0, 6, 4]
#  the query for 4:
# selected bidder id:0
# bidder 0 bidding:5 spent : 75/75 : [0, 6, 4]
#  the query for 1:
# selected bidder id:7
# bidder 7 bidding:12 spent : 96/288 : [3, 1]
#  the query for 4:
# selected bidder id:2
# bidder 2 bidding:12 spent : 12/312 : [4, 6, 2]
#  the query for 1:
# selected bidder id:7
# bidder 7 bidding:12 spent : 108/288 : [3, 1]
#  the query for 1:
# selected bidder id:7
# bidder 7 bidding:12 spent : 120/288 : [3, 1]
#  the query for 4:
# selected bidder id:2
# bidder 2 bidding:12 spent : 24/312 : [4, 6, 2]
#  the query for 5:
# selected bidder id:4
# bidder 4 bidding:6 spent : 96/144 : [5, 2, 8]
#  the query for 7:
# selected bidder id:8
# bidder 8 bidding:9 spent : 72/126 : [7, 3, 8]
#  the query for 5:
# selected bidder id:4
# bidder 4 bidding:6 spent : 102/144 : [5, 2, 8]
#  the query for 8:
# selected bidder id:4
# bidder 4 bidding:6 spent : 108/144 : [5, 2, 8]
#  the query for 5:
# selected bidder id:4
# bidder 4 bidding:6 spent : 114/144 : [5, 2, 8]
#  the query for 4:
# selected bidder id:2
# bidder 2 bidding:12 spent : 36/312 : [4, 6, 2]
#  the query for 2:
# selected bidder id:4
# bidder 4 bidding:6 spent : 120/144 : [5, 2, 8]
#  the query for 8:
# selected bidder id:4
# bidder 4 bidding:6 spent : 126/144 : [5, 2, 8]
#  the query for 4:
# selected bidder id:2
# bidder 2 bidding:12 spent : 48/312 : [4, 6, 2]
#  the query for 9:
# bidders all inactive
#  the query for 7:
# selected bidder id:8
# bidder 8 bidding:9 spent : 81/126 : [7, 3, 8]
#  the query for 3:
# selected bidder id:8
# bidder 8 bidding:9 spent : 90/126 : [7, 3, 8]
#  the query for 0:
# selected bidder id:6
# bidder 6 bidding:16 spent : 16/272 : [2, 0, 1]
#  the query for 0:
# selected bidder id:6
# bidder 6 bidding:16 spent : 32/272 : [2, 0, 1]
#  the query for 8:
# selected bidder id:4
# bidder 4 bidding:6 spent : 132/144 : [5, 2, 8]
#  the query for 7:
# selected bidder id:8
# bidder 8 bidding:9 spent : 99/126 : [7, 3, 8]
#  the query for 6:
# selected bidder id:2
# bidder 2 bidding:12 spent : 60/312 : [4, 6, 2]
#  the query for 2:
# selected bidder id:4
# bidder 4 bidding:6 spent : 138/144 : [5, 2, 8]
#  the query for 2:
# selected bidder id:4
# bidder 4 bidding:6 spent : 144/144 : [5, 2, 8]
#  the query for 8:
# selected bidder id:8
# bidder 8 bidding:9 spent : 108/126 : [7, 3, 8]
#  the query for 5:
# bidders all inactive
#  the query for 4:
# selected bidder id:2
# bidder 2 bidding:12 spent : 72/312 : [4, 6, 2]
#  the query for 4:
# selected bidder id:2
# bidder 2 bidding:12 spent : 84/312 : [4, 6, 2]
#  the query for 2:
# selected bidder id:2
# bidder 2 bidding:12 spent : 96/312 : [4, 6, 2]
#  the query for 4:
# selected bidder id:2
# bidder 2 bidding:12 spent : 108/312 : [4, 6, 2]
#  the query for 6:
# selected bidder id:2
# bidder 2 bidding:12 spent : 120/312 : [4, 6, 2]
#  the query for 4:
# selected bidder id:2
# bidder 2 bidding:12 spent : 132/312 : [4, 6, 2]
#  the query for 4:
# selected bidder id:2
# bidder 2 bidding:12 spent : 144/312 : [4, 6, 2]
#  the query for 3:
# selected bidder id:8
# bidder 8 bidding:9 spent : 117/126 : [7, 3, 8]
#  the query for 8:
# selected bidder id:8
# bidder 8 bidding:9 spent : 126/126 : [7, 3, 8]
#  the query for 6:
# selected bidder id:2
# bidder 2 bidding:12 spent : 156/312 : [4, 6, 2]
#  the query for 0:
# selected bidder id:6
# bidder 6 bidding:16 spent : 48/272 : [2, 0, 1]
#  the query for 4:
# selected bidder id:2
# bidder 2 bidding:12 spent : 168/312 : [4, 6, 2]
#  the query for 8:
# selected bidder id:3
# bidder 3 bidding:12 spent : 12/216 : [2, 8, 6]
#  the query for 6:
# selected bidder id:2
# bidder 2 bidding:12 spent : 180/312 : [4, 6, 2]
#  the query for 5:
# bidders all inactive
#  the query for 7:
# bidders all inactive
#  the query for 7:
# bidders all inactive
#  the query for 3:
# selected bidder id:7
# bidder 7 bidding:12 spent : 132/288 : [3, 1]
#  the query for 6:
# selected bidder id:2
# bidder 2 bidding:12 spent : 192/312 : [4, 6, 2]
#  the query for 4:
# selected bidder id:2
# bidder 2 bidding:12 spent : 204/312 : [4, 6, 2]
#  the query for 1:
# selected bidder id:7
# bidder 7 bidding:12 spent : 144/288 : [3, 1]
#  the query for 2:
# selected bidder id:2
# bidder 2 bidding:12 spent : 216/312 : [4, 6, 2]
#  the query for 2:
# selected bidder id:2
# bidder 2 bidding:12 spent : 228/312 : [4, 6, 2]
#  the query for 2:
# selected bidder id:2
# bidder 2 bidding:12 spent : 240/312 : [4, 6, 2]
#  the query for 9:
# bidders all inactive
#  the query for 2:
# selected bidder id:2
# bidder 2 bidding:12 spent : 252/312 : [4, 6, 2]
#  the query for 4:
# selected bidder id:2
# bidder 2 bidding:12 spent : 264/312 : [4, 6, 2]
#  the query for 8:
# selected bidder id:3
# bidder 3 bidding:12 spent : 24/216 : [2, 8, 6]
#  the query for 3:
# selected bidder id:7
# bidder 7 bidding:12 spent : 156/288 : [3, 1]
#  the query for 2:
# selected bidder id:2
# bidder 2 bidding:12 spent : 276/312 : [4, 6, 2]
#  the query for 5:
# bidders all inactive
#  the query for 8:
# selected bidder id:3
# bidder 3 bidding:12 spent : 36/216 : [2, 8, 6]
#  the query for 0:
# selected bidder id:6
# bidder 6 bidding:16 spent : 64/272 : [2, 0, 1]
#  the query for 1:
# selected bidder id:7
# bidder 7 bidding:12 spent : 168/288 : [3, 1]
#  the query for 2:
# selected bidder id:2
# bidder 2 bidding:12 spent : 288/312 : [4, 6, 2]
#  the query for 2:
# selected bidder id:2
# bidder 2 bidding:12 spent : 300/312 : [4, 6, 2]
#  the query for 6:
# selected bidder id:2
# bidder 2 bidding:12 spent : 312/312 : [4, 6, 2]
#  the query for 1:
# selected bidder id:7
# bidder 7 bidding:12 spent : 180/288 : [3, 1]
#  the query for 4:
# selected bidder id:1
# bidder 1 bidding:19 spent : 19/342 : [6, 8, 4]
#  the query for 4:
# selected bidder id:1
# bidder 1 bidding:19 spent : 38/342 : [6, 8, 4]
#  the query for 8:
# selected bidder id:3
# bidder 3 bidding:12 spent : 48/216 : [2, 8, 6]
#  the query for 3:
# selected bidder id:7
# bidder 7 bidding:12 spent : 192/288 : [3, 1]
#  the query for 9:
# bidders all inactive
#  the query for 8:
# selected bidder id:3
# bidder 3 bidding:12 spent : 60/216 : [2, 8, 6]
#  the query for 3:
# selected bidder id:7
# bidder 7 bidding:12 spent : 204/288 : [3, 1]
#  the query for 2:
# selected bidder id:3
# bidder 3 bidding:12 spent : 72/216 : [2, 8, 6]
#  the query for 5:
# bidders all inactive
#  the query for 8:
# selected bidder id:3
# bidder 3 bidding:12 spent : 84/216 : [2, 8, 6]
# TOTAL GAINS IS 1167
# bidder 0 bidding:7 spent : 0/140 : [9, 2, 8]
# bidder 1 bidding:17 spent : 0/204 : [1, 3, 4]
# bidder 2 bidding:7 spent : 0/168 : [5, 3, 8]
# bidder 3 bidding:15 spent : 0/75 : [6, 9, 3]
# bidder 4 bidding:18 spent : 0/450 : [5, 9, 7]
# bidder 5 bidding:10 spent : 0/200 : [5, 4, 7]
# bidder 6 bidding:18 spent : 0/414 : [7, 3, 8]
# bidder 7 bidding:10 spent : 0/120 : [1, 7, 3]
# bidder 8 bidding:5 spent : 0/45 : [9, 7, 0]
# bidder 9 bidding:11 spent : 0/297 : [8, 9, 7]
#  the query for 1:
# selected bidder id:7
# bidder 7 bidding:10 spent : 10/120 : [1, 7, 3]
#  the query for 0:
# selected bidder id:8
# bidder 8 bidding:5 spent : 5/45 : [9, 7, 0]
#  the query for 8:
# selected bidder id:0
# bidder 0 bidding:7 spent : 7/140 : [9, 2, 8]
#  the query for 2:
# selected bidder id:0
# bidder 0 bidding:7 spent : 14/140 : [9, 2, 8]
#  the query for 6:
# selected bidder id:3
# bidder 3 bidding:15 spent : 15/75 : [6, 9, 3]
#  the query for 3:
# selected bidder id:2
# bidder 2 bidding:7 spent : 7/168 : [5, 3, 8]
#  the query for 0:
# selected bidder id:8
# bidder 8 bidding:5 spent : 10/45 : [9, 7, 0]
#  the query for 3:
# selected bidder id:2
# bidder 2 bidding:7 spent : 14/168 : [5, 3, 8]
#  the query for 8:
# selected bidder id:0
# bidder 0 bidding:7 spent : 21/140 : [9, 2, 8]
#  the query for 8:
# selected bidder id:0
# bidder 0 bidding:7 spent : 28/140 : [9, 2, 8]
#  the query for 3:
# selected bidder id:2
# bidder 2 bidding:7 spent : 21/168 : [5, 3, 8]
#  the query for 3:
# selected bidder id:2
# bidder 2 bidding:7 spent : 28/168 : [5, 3, 8]
#  the query for 2:
# selected bidder id:0
# bidder 0 bidding:7 spent : 35/140 : [9, 2, 8]
#  the query for 6:
# selected bidder id:3
# bidder 3 bidding:15 spent : 30/75 : [6, 9, 3]
#  the query for 0:
# selected bidder id:8
# bidder 8 bidding:5 spent : 15/45 : [9, 7, 0]
#  the query for 9:
# selected bidder id:8
# bidder 8 bidding:5 spent : 20/45 : [9, 7, 0]
#  the query for 7:
# selected bidder id:8
# bidder 8 bidding:5 spent : 25/45 : [9, 7, 0]
#  the query for 1:
# selected bidder id:7
# bidder 7 bidding:10 spent : 20/120 : [1, 7, 3]
#  the query for 7:
# selected bidder id:8
# bidder 8 bidding:5 spent : 30/45 : [9, 7, 0]
#  the query for 0:
# selected bidder id:8
# bidder 8 bidding:5 spent : 35/45 : [9, 7, 0]
#  the query for 1:
# selected bidder id:7
# bidder 7 bidding:10 spent : 30/120 : [1, 7, 3]
#  the query for 5:
# selected bidder id:2
# bidder 2 bidding:7 spent : 35/168 : [5, 3, 8]
#  the query for 1:
# selected bidder id:7
# bidder 7 bidding:10 spent : 40/120 : [1, 7, 3]
#  the query for 9:
# selected bidder id:8
# bidder 8 bidding:5 spent : 40/45 : [9, 7, 0]
#  the query for 1:
# selected bidder id:7
# bidder 7 bidding:10 spent : 50/120 : [1, 7, 3]
#  the query for 5:
# selected bidder id:2
# bidder 2 bidding:7 spent : 42/168 : [5, 3, 8]
#  the query for 0:
# selected bidder id:8
# bidder 8 bidding:5 spent : 45/45 : [9, 7, 0]
#  the query for 4:
# selected bidder id:5
# bidder 5 bidding:10 spent : 10/200 : [5, 4, 7]
#  the query for 7:
# selected bidder id:7
# bidder 7 bidding:10 spent : 60/120 : [1, 7, 3]
#  the query for 2:
# selected bidder id:0
# bidder 0 bidding:7 spent : 42/140 : [9, 2, 8]
#  the query for 3:
# selected bidder id:7
# bidder 7 bidding:10 spent : 70/120 : [1, 7, 3]
#  the query for 9:
# selected bidder id:0
# bidder 0 bidding:7 spent : 49/140 : [9, 2, 8]
#  the query for 4:
# selected bidder id:5
# bidder 5 bidding:10 spent : 20/200 : [5, 4, 7]
#  the query for 3:
# selected bidder id:7
# bidder 7 bidding:10 spent : 80/120 : [1, 7, 3]
#  the query for 4:
# selected bidder id:5
# bidder 5 bidding:10 spent : 30/200 : [5, 4, 7]
#  the query for 2:
# selected bidder id:0
# bidder 0 bidding:7 spent : 56/140 : [9, 2, 8]
#  the query for 2:
# selected bidder id:0
# bidder 0 bidding:7 spent : 63/140 : [9, 2, 8]
#  the query for 4:
# selected bidder id:5
# bidder 5 bidding:10 spent : 40/200 : [5, 4, 7]
#  the query for 0:
# bidders all inactive
#  the query for 3:
# selected bidder id:7
# bidder 7 bidding:10 spent : 90/120 : [1, 7, 3]
#  the query for 3:
# selected bidder id:7
# bidder 7 bidding:10 spent : 100/120 : [1, 7, 3]
#  the query for 9:
# selected bidder id:0
# bidder 0 bidding:7 spent : 70/140 : [9, 2, 8]
#  the query for 4:
# selected bidder id:5
# bidder 5 bidding:10 spent : 50/200 : [5, 4, 7]
#  the query for 8:
# selected bidder id:0
# bidder 0 bidding:7 spent : 77/140 : [9, 2, 8]
#  the query for 3:
# selected bidder id:7
# bidder 7 bidding:10 spent : 110/120 : [1, 7, 3]
#  the query for 6:
# selected bidder id:3
# bidder 3 bidding:15 spent : 45/75 : [6, 9, 3]
#  the query for 5:
# selected bidder id:2
# bidder 2 bidding:7 spent : 49/168 : [5, 3, 8]
#  the query for 4:
# selected bidder id:5
# bidder 5 bidding:10 spent : 60/200 : [5, 4, 7]
#  the query for 3:
# selected bidder id:7
# bidder 7 bidding:10 spent : 120/120 : [1, 7, 3]
#  the query for 3:
# selected bidder id:2
# bidder 2 bidding:7 spent : 56/168 : [5, 3, 8]
#  the query for 8:
# selected bidder id:0
# bidder 0 bidding:7 spent : 84/140 : [9, 2, 8]
#  the query for 2:
# selected bidder id:0
# bidder 0 bidding:7 spent : 91/140 : [9, 2, 8]
#  the query for 0:
# bidders all inactive
#  the query for 8:
# selected bidder id:0
# bidder 0 bidding:7 spent : 98/140 : [9, 2, 8]
#  the query for 8:
# selected bidder id:0
# bidder 0 bidding:7 spent : 105/140 : [9, 2, 8]
#  the query for 6:
# selected bidder id:3
# bidder 3 bidding:15 spent : 60/75 : [6, 9, 3]
#  the query for 3:
# selected bidder id:3
# bidder 3 bidding:15 spent : 75/75 : [6, 9, 3]
#  the query for 1:
# selected bidder id:1
# bidder 1 bidding:17 spent : 17/204 : [1, 3, 4]
#  the query for 9:
# selected bidder id:0
# bidder 0 bidding:7 spent : 112/140 : [9, 2, 8]
#  the query for 9:
# selected bidder id:0
# bidder 0 bidding:7 spent : 119/140 : [9, 2, 8]
#  the query for 7:
# selected bidder id:5
# bidder 5 bidding:10 spent : 70/200 : [5, 4, 7]
#  the query for 5:
# selected bidder id:2
# bidder 2 bidding:7 spent : 63/168 : [5, 3, 8]
#  the query for 5:
# selected bidder id:2
# bidder 2 bidding:7 spent : 70/168 : [5, 3, 8]
#  the query for 0:
# bidders all inactive
#  the query for 2:
# selected bidder id:0
# bidder 0 bidding:7 spent : 126/140 : [9, 2, 8]
#  the query for 3:
# selected bidder id:2
# bidder 2 bidding:7 spent : 77/168 : [5, 3, 8]
#  the query for 5:
# selected bidder id:2
# bidder 2 bidding:7 spent : 84/168 : [5, 3, 8]
#  the query for 8:
# selected bidder id:0
# bidder 0 bidding:7 spent : 133/140 : [9, 2, 8]
#  the query for 0:
# bidders all inactive
#  the query for 9:
# selected bidder id:0
# bidder 0 bidding:7 spent : 140/140 : [9, 2, 8]
#  the query for 7:
# selected bidder id:5
# bidder 5 bidding:10 spent : 80/200 : [5, 4, 7]
#  the query for 0:
# bidders all inactive
#  the query for 6:
# bidders all inactive
#  the query for 5:
# selected bidder id:2
# bidder 2 bidding:7 spent : 91/168 : [5, 3, 8]
#  the query for 9:
# selected bidder id:9
# bidder 9 bidding:11 spent : 11/297 : [8, 9, 7]
#  the query for 6:
# bidders all inactive
#  the query for 2:
# bidders all inactive
#  the query for 5:
# selected bidder id:2
# bidder 2 bidding:7 spent : 98/168 : [5, 3, 8]
#  the query for 1:
# selected bidder id:1
# bidder 1 bidding:17 spent : 34/204 : [1, 3, 4]
#  the query for 4:
# selected bidder id:5
# bidder 5 bidding:10 spent : 90/200 : [5, 4, 7]
#  the query for 9:
# selected bidder id:9
# bidder 9 bidding:11 spent : 22/297 : [8, 9, 7]
#  the query for 0:
# bidders all inactive
#  the query for 8:
# selected bidder id:2
# bidder 2 bidding:7 spent : 105/168 : [5, 3, 8]
#  the query for 0:
# bidders all inactive
#  the query for 0:
# bidders all inactive
#  the query for 5:
# selected bidder id:2
# bidder 2 bidding:7 spent : 112/168 : [5, 3, 8]
#  the query for 3:
# selected bidder id:2
# bidder 2 bidding:7 spent : 119/168 : [5, 3, 8]
#  the query for 1:
# selected bidder id:1
# bidder 1 bidding:17 spent : 51/204 : [1, 3, 4]
#  the query for 5:
# selected bidder id:2
# bidder 2 bidding:7 spent : 126/168 : [5, 3, 8]
#  the query for 6:
# bidders all inactive
#  the query for 3:
# selected bidder id:2
# bidder 2 bidding:7 spent : 133/168 : [5, 3, 8]
#  the query for 0:
# bidders all inactive
#  the query for 5:
# selected bidder id:2
# bidder 2 bidding:7 spent : 140/168 : [5, 3, 8]
#  the query for 8:
# selected bidder id:2
# bidder 2 bidding:7 spent : 147/168 : [5, 3, 8]
#  the query for 9:
# selected bidder id:9
# bidder 9 bidding:11 spent : 33/297 : [8, 9, 7]
#  the query for 6:
# bidders all inactive
#  the query for 2:
# bidders all inactive
#  the query for 7:
# selected bidder id:5
# bidder 5 bidding:10 spent : 100/200 : [5, 4, 7]
#  the query for 8:
# selected bidder id:2
# bidder 2 bidding:7 spent : 154/168 : [5, 3, 8]
#  the query for 8:
# selected bidder id:2
# bidder 2 bidding:7 spent : 161/168 : [5, 3, 8]
#  the query for 0:
# bidders all inactive
#  the query for 9:
# selected bidder id:9
# bidder 9 bidding:11 spent : 44/297 : [8, 9, 7]
#  the query for 2:
# bidders all inactive
#  the query for 1:
# selected bidder id:1
# bidder 1 bidding:17 spent : 68/204 : [1, 3, 4]
#  the query for 5:
# selected bidder id:2
# bidder 2 bidding:7 spent : 168/168 : [5, 3, 8]
#  the query for 3:
# selected bidder id:1
# bidder 1 bidding:17 spent : 85/204 : [1, 3, 4]
#  the query for 2:
# bidders all inactive
#  the query for 5:
# selected bidder id:5
# bidder 5 bidding:10 spent : 110/200 : [5, 4, 7]
#  the query for 3:
# selected bidder id:1
# bidder 1 bidding:17 spent : 102/204 : [1, 3, 4]
#  the query for 8:
# selected bidder id:9
# bidder 9 bidding:11 spent : 55/297 : [8, 9, 7]
#  the query for 2:
# bidders all inactive
#  the query for 3:
# selected bidder id:1
# bidder 1 bidding:17 spent : 119/204 : [1, 3, 4]
#  the query for 4:
# selected bidder id:5
# bidder 5 bidding:10 spent : 120/200 : [5, 4, 7]
#  the query for 0:
# bidders all inactive
#  the query for 8:
# selected bidder id:9
# bidder 9 bidding:11 spent : 66/297 : [8, 9, 7]
#  the query for 0:
# bidders all inactive
#  the query for 1:
# selected bidder id:1
# bidder 1 bidding:17 spent : 136/204 : [1, 3, 4]
#  the query for 2:
# bidders all inactive
#  the query for 9:
# selected bidder id:9
# bidder 9 bidding:11 spent : 77/297 : [8, 9, 7]
#  the query for 8:
# selected bidder id:9
# bidder 9 bidding:11 spent : 88/297 : [8, 9, 7]
#  the query for 3:
# selected bidder id:1
# bidder 1 bidding:17 spent : 153/204 : [1, 3, 4]
#  the query for 7:
# selected bidder id:5
# bidder 5 bidding:10 spent : 130/200 : [5, 4, 7]
#  the query for 1:
# selected bidder id:1
# bidder 1 bidding:17 spent : 170/204 : [1, 3, 4]
#  the query for 9:
# selected bidder id:9
# bidder 9 bidding:11 spent : 99/297 : [8, 9, 7]
#  the query for 3:
# selected bidder id:1
# bidder 1 bidding:17 spent : 187/204 : [1, 3, 4]
#  the query for 6:
# bidders all inactive
#  the query for 2:
# bidders all inactive
#  the query for 3:
# selected bidder id:1
# bidder 1 bidding:17 spent : 204/204 : [1, 3, 4]
#  the query for 8:
# selected bidder id:9
# bidder 9 bidding:11 spent : 110/297 : [8, 9, 7]
#  the query for 1:
# bidders all inactive
#  the query for 8:
# selected bidder id:9
# bidder 9 bidding:11 spent : 121/297 : [8, 9, 7]
#  the query for 3:
# selected bidder id:6
# bidder 6 bidding:18 spent : 18/414 : [7, 3, 8]
#  the query for 8:
# selected bidder id:9
# bidder 9 bidding:11 spent : 132/297 : [8, 9, 7]
#  the query for 2:
# bidders all inactive
#  the query for 5:
# selected bidder id:5
# bidder 5 bidding:10 spent : 140/200 : [5, 4, 7]
#  the query for 9:
# selected bidder id:9
# bidder 9 bidding:11 spent : 143/297 : [8, 9, 7]
#  the query for 8:
# selected bidder id:9
# bidder 9 bidding:11 spent : 154/297 : [8, 9, 7]
#  the query for 7:
# selected bidder id:5
# bidder 5 bidding:10 spent : 150/200 : [5, 4, 7]
#  the query for 3:
# selected bidder id:6
# bidder 6 bidding:18 spent : 36/414 : [7, 3, 8]
#  the query for 2:
# bidders all inactive
#  the query for 6:
# bidders all inactive
#  the query for 3:
# selected bidder id:6
# bidder 6 bidding:18 spent : 54/414 : [7, 3, 8]
#  the query for 1:
# bidders all inactive
#  the query for 5:
# selected bidder id:5
# bidder 5 bidding:10 spent : 160/200 : [5, 4, 7]
#  the query for 9:
# selected bidder id:9
# bidder 9 bidding:11 spent : 165/297 : [8, 9, 7]
#  the query for 3:
# selected bidder id:6
# bidder 6 bidding:18 spent : 72/414 : [7, 3, 8]
#  the query for 3:
# selected bidder id:6
# bidder 6 bidding:18 spent : 90/414 : [7, 3, 8]
#  the query for 9:
# selected bidder id:9
# bidder 9 bidding:11 spent : 176/297 : [8, 9, 7]
#  the query for 9:
# selected bidder id:9
# bidder 9 bidding:11 spent : 187/297 : [8, 9, 7]
#  the query for 5:
# selected bidder id:5
# bidder 5 bidding:10 spent : 170/200 : [5, 4, 7]
# TOTAL GAINS IS 1199
# bidder 0 bidding:10 spent : 0/80 : [7, 5]
# bidder 1 bidding:4 spent : 0/36 : [4, 2, 5]
# bidder 2 bidding:14 spent : 0/182 : [1, 5, 2]
# bidder 3 bidding:8 spent : 0/176 : [6, 0, 9]
# bidder 4 bidding:18 spent : 0/252 : [0, 3]
# bidder 5 bidding:18 spent : 0/108 : [0, 5, 7]
# bidder 6 bidding:2 spent : 0/20 : [2, 0, 6]
# bidder 7 bidding:5 spent : 0/95 : [6, 2]
# bidder 8 bidding:14 spent : 0/406 : [4, 2, 7]
# bidder 9 bidding:10 spent : 0/190 : [0, 8, 2]
#  the query for 5:
# selected bidder id:1
# bidder 1 bidding:4 spent : 4/36 : [4, 2, 5]
#  the query for 0:
# selected bidder id:6
# bidder 6 bidding:2 spent : 2/20 : [2, 0, 6]
#  the query for 6:
# selected bidder id:6
# bidder 6 bidding:2 spent : 4/20 : [2, 0, 6]
#  the query for 2:
# selected bidder id:6
# bidder 6 bidding:2 spent : 6/20 : [2, 0, 6]
#  the query for 3:
# selected bidder id:4
# bidder 4 bidding:18 spent : 18/252 : [0, 3]
#  the query for 1:
# selected bidder id:2
# bidder 2 bidding:14 spent : 14/182 : [1, 5, 2]
#  the query for 4:
# selected bidder id:1
# bidder 1 bidding:4 spent : 8/36 : [4, 2, 5]
#  the query for 0:
# selected bidder id:6
# bidder 6 bidding:2 spent : 8/20 : [2, 0, 6]
#  the query for 4:
# selected bidder id:1
# bidder 1 bidding:4 spent : 12/36 : [4, 2, 5]
#  the query for 9:
# selected bidder id:3
# bidder 3 bidding:8 spent : 8/176 : [6, 0, 9]
#  the query for 9:
# selected bidder id:3
# bidder 3 bidding:8 spent : 16/176 : [6, 0, 9]
#  the query for 2:
# selected bidder id:6
# bidder 6 bidding:2 spent : 10/20 : [2, 0, 6]
#  the query for 6:
# selected bidder id:6
# bidder 6 bidding:2 spent : 12/20 : [2, 0, 6]
#  the query for 0:
# selected bidder id:6
# bidder 6 bidding:2 spent : 14/20 : [2, 0, 6]
#  the query for 6:
# selected bidder id:6
# bidder 6 bidding:2 spent : 16/20 : [2, 0, 6]
#  the query for 3:
# selected bidder id:4
# bidder 4 bidding:18 spent : 36/252 : [0, 3]
#  the query for 7:
# selected bidder id:0
# bidder 0 bidding:10 spent : 10/80 : [7, 5]
#  the query for 3:
# selected bidder id:4
# bidder 4 bidding:18 spent : 54/252 : [0, 3]
#  the query for 2:
# selected bidder id:6
# bidder 6 bidding:2 spent : 18/20 : [2, 0, 6]
#  the query for 9:
# selected bidder id:3
# bidder 3 bidding:8 spent : 24/176 : [6, 0, 9]
#  the query for 7:
# selected bidder id:0
# bidder 0 bidding:10 spent : 20/80 : [7, 5]
#  the query for 7:
# selected bidder id:0
# bidder 0 bidding:10 spent : 30/80 : [7, 5]
#  the query for 2:
# selected bidder id:6
# bidder 6 bidding:2 spent : 20/20 : [2, 0, 6]
#  the query for 2:
# selected bidder id:1
# bidder 1 bidding:4 spent : 16/36 : [4, 2, 5]
#  the query for 1:
# selected bidder id:2
# bidder 2 bidding:14 spent : 28/182 : [1, 5, 2]
#  the query for 3:
# selected bidder id:4
# bidder 4 bidding:18 spent : 72/252 : [0, 3]
#  the query for 1:
# selected bidder id:2
# bidder 2 bidding:14 spent : 42/182 : [1, 5, 2]
#  the query for 1:
# selected bidder id:2
# bidder 2 bidding:14 spent : 56/182 : [1, 5, 2]
#  the query for 3:
# selected bidder id:4
# bidder 4 bidding:18 spent : 90/252 : [0, 3]
#  the query for 3:
# selected bidder id:4
# bidder 4 bidding:18 spent : 108/252 : [0, 3]
#  the query for 9:
# selected bidder id:3
# bidder 3 bidding:8 spent : 32/176 : [6, 0, 9]
#  the query for 9:
# selected bidder id:3
# bidder 3 bidding:8 spent : 40/176 : [6, 0, 9]
#  the query for 3:
# selected bidder id:4
# bidder 4 bidding:18 spent : 126/252 : [0, 3]
#  the query for 8:
# selected bidder id:9
# bidder 9 bidding:10 spent : 10/190 : [0, 8, 2]
#  the query for 7:
# selected bidder id:0
# bidder 0 bidding:10 spent : 40/80 : [7, 5]
#  the query for 2:
# selected bidder id:1
# bidder 1 bidding:4 spent : 20/36 : [4, 2, 5]
#  the query for 9:
# selected bidder id:3
# bidder 3 bidding:8 spent : 48/176 : [6, 0, 9]
#  the query for 6:
# selected bidder id:3
# bidder 3 bidding:8 spent : 56/176 : [6, 0, 9]
#  the query for 9:
# selected bidder id:3
# bidder 3 bidding:8 spent : 64/176 : [6, 0, 9]
#  the query for 4:
# selected bidder id:1
# bidder 1 bidding:4 spent : 24/36 : [4, 2, 5]
#  the query for 3:
# selected bidder id:4
# bidder 4 bidding:18 spent : 144/252 : [0, 3]
#  the query for 0:
# selected bidder id:3
# bidder 3 bidding:8 spent : 72/176 : [6, 0, 9]
#  the query for 1:
# selected bidder id:2
# bidder 2 bidding:14 spent : 70/182 : [1, 5, 2]
#  the query for 2:
# selected bidder id:1
# bidder 1 bidding:4 spent : 28/36 : [4, 2, 5]
#  the query for 5:
# selected bidder id:1
# bidder 1 bidding:4 spent : 32/36 : [4, 2, 5]
#  the query for 3:
# selected bidder id:4
# bidder 4 bidding:18 spent : 162/252 : [0, 3]
#  the query for 4:
# selected bidder id:1
# bidder 1 bidding:4 spent : 36/36 : [4, 2, 5]
#  the query for 3:
# selected bidder id:4
# bidder 4 bidding:18 spent : 180/252 : [0, 3]
#  the query for 1:
# selected bidder id:2
# bidder 2 bidding:14 spent : 84/182 : [1, 5, 2]
#  the query for 0:
# selected bidder id:4
# bidder 4 bidding:18 spent : 198/252 : [0, 3]
#  the query for 0:
# selected bidder id:4
# bidder 4 bidding:18 spent : 216/252 : [0, 3]
#  the query for 3:
# selected bidder id:4
# bidder 4 bidding:18 spent : 234/252 : [0, 3]
#  the query for 5:
# selected bidder id:0
# bidder 0 bidding:10 spent : 50/80 : [7, 5]
#  the query for 8:
# selected bidder id:9
# bidder 9 bidding:10 spent : 20/190 : [0, 8, 2]
#  the query for 8:
# selected bidder id:9
# bidder 9 bidding:10 spent : 30/190 : [0, 8, 2]
#  the query for 7:
# selected bidder id:0
# bidder 0 bidding:10 spent : 60/80 : [7, 5]
#  the query for 4:
# selected bidder id:8
# bidder 8 bidding:14 spent : 14/406 : [4, 2, 7]
#  the query for 7:
# selected bidder id:0
# bidder 0 bidding:10 spent : 70/80 : [7, 5]
#  the query for 5:
# selected bidder id:0
# bidder 0 bidding:10 spent : 80/80 : [7, 5]
#  the query for 8:
# selected bidder id:9
# bidder 9 bidding:10 spent : 40/190 : [0, 8, 2]
#  the query for 4:
# selected bidder id:8
# bidder 8 bidding:14 spent : 28/406 : [4, 2, 7]
#  the query for 0:
# selected bidder id:4
# bidder 4 bidding:18 spent : 252/252 : [0, 3]
#  the query for 3:
# bidders all inactive
#  the query for 3:
# bidders all inactive
#  the query for 5:
# selected bidder id:2
# bidder 2 bidding:14 spent : 98/182 : [1, 5, 2]
#  the query for 2:
# selected bidder id:2
# bidder 2 bidding:14 spent : 112/182 : [1, 5, 2]
#  the query for 7:
# selected bidder id:8
# bidder 8 bidding:14 spent : 42/406 : [4, 2, 7]
#  the query for 5:
# selected bidder id:2
# bidder 2 bidding:14 spent : 126/182 : [1, 5, 2]
#  the query for 9:
# selected bidder id:3
# bidder 3 bidding:8 spent : 80/176 : [6, 0, 9]
#  the query for 7:
# selected bidder id:8
# bidder 8 bidding:14 spent : 56/406 : [4, 2, 7]
#  the query for 5:
# selected bidder id:2
# bidder 2 bidding:14 spent : 140/182 : [1, 5, 2]
#  the query for 4:
# selected bidder id:8
# bidder 8 bidding:14 spent : 70/406 : [4, 2, 7]
#  the query for 7:
# selected bidder id:8
# bidder 8 bidding:14 spent : 84/406 : [4, 2, 7]
#  the query for 4:
# selected bidder id:8
# bidder 8 bidding:14 spent : 98/406 : [4, 2, 7]
#  the query for 5:
# selected bidder id:2
# bidder 2 bidding:14 spent : 154/182 : [1, 5, 2]
#  the query for 3:
# bidders all inactive
#  the query for 8:
# selected bidder id:9
# bidder 9 bidding:10 spent : 50/190 : [0, 8, 2]
#  the query for 4:
# selected bidder id:8
# bidder 8 bidding:14 spent : 112/406 : [4, 2, 7]
#  the query for 8:
# selected bidder id:9
# bidder 9 bidding:10 spent : 60/190 : [0, 8, 2]
#  the query for 0:
# selected bidder id:3
# bidder 3 bidding:8 spent : 88/176 : [6, 0, 9]
#  the query for 7:
# selected bidder id:8
# bidder 8 bidding:14 spent : 126/406 : [4, 2, 7]
#  the query for 1:
# selected bidder id:2
# bidder 2 bidding:14 spent : 168/182 : [1, 5, 2]
#  the query for 7:
# selected bidder id:8
# bidder 8 bidding:14 spent : 140/406 : [4, 2, 7]
#  the query for 5:
# selected bidder id:2
# bidder 2 bidding:14 spent : 182/182 : [1, 5, 2]
#  the query for 9:
# selected bidder id:3
# bidder 3 bidding:8 spent : 96/176 : [6, 0, 9]
#  the query for 8:
# selected bidder id:9
# bidder 9 bidding:10 spent : 70/190 : [0, 8, 2]
#  the query for 7:
# selected bidder id:8
# bidder 8 bidding:14 spent : 154/406 : [4, 2, 7]
#  the query for 8:
# selected bidder id:9
# bidder 9 bidding:10 spent : 80/190 : [0, 8, 2]
#  the query for 6:
# selected bidder id:3
# bidder 3 bidding:8 spent : 104/176 : [6, 0, 9]
#  the query for 1:
# bidders all inactive
#  the query for 0:
# selected bidder id:3
# bidder 3 bidding:8 spent : 112/176 : [6, 0, 9]
#  the query for 1:
# bidders all inactive
#  the query for 4:
# selected bidder id:8
# bidder 8 bidding:14 spent : 168/406 : [4, 2, 7]
#  the query for 0:
# selected bidder id:3
# bidder 3 bidding:8 spent : 120/176 : [6, 0, 9]
#  the query for 3:
# bidders all inactive
#  the query for 1:
# bidders all inactive
#  the query for 5:
# selected bidder id:5
# bidder 5 bidding:18 spent : 18/108 : [0, 5, 7]
#  the query for 5:
# selected bidder id:5
# bidder 5 bidding:18 spent : 36/108 : [0, 5, 7]
#  the query for 6:
# selected bidder id:3
# bidder 3 bidding:8 spent : 128/176 : [6, 0, 9]
#  the query for 5:
# selected bidder id:5
# bidder 5 bidding:18 spent : 54/108 : [0, 5, 7]
#  the query for 9:
# selected bidder id:3
# bidder 3 bidding:8 spent : 136/176 : [6, 0, 9]
#  the query for 3:
# bidders all inactive
#  the query for 1:
# bidders all inactive
#  the query for 2:
# selected bidder id:9
# bidder 9 bidding:10 spent : 90/190 : [0, 8, 2]
#  the query for 4:
# selected bidder id:8
# bidder 8 bidding:14 spent : 182/406 : [4, 2, 7]
#  the query for 8:
# selected bidder id:9
# bidder 9 bidding:10 spent : 100/190 : [0, 8, 2]
#  the query for 5:
# selected bidder id:5
# bidder 5 bidding:18 spent : 72/108 : [0, 5, 7]
#  the query for 6:
# selected bidder id:3
# bidder 3 bidding:8 spent : 144/176 : [6, 0, 9]
#  the query for 0:
# selected bidder id:3
# bidder 3 bidding:8 spent : 152/176 : [6, 0, 9]
#  the query for 6:
# selected bidder id:3
# bidder 3 bidding:8 spent : 160/176 : [6, 0, 9]
#  the query for 0:
# selected bidder id:3
# bidder 3 bidding:8 spent : 168/176 : [6, 0, 9]
#  the query for 3:
# bidders all inactive
#  the query for 9:
# selected bidder id:3
# bidder 3 bidding:8 spent : 176/176 : [6, 0, 9]
#  the query for 7:
# selected bidder id:5
# bidder 5 bidding:18 spent : 90/108 : [0, 5, 7]
#  the query for 2:
# selected bidder id:9
# bidder 9 bidding:10 spent : 110/190 : [0, 8, 2]
#  the query for 5:
# selected bidder id:5
# bidder 5 bidding:18 spent : 108/108 : [0, 5, 7]
#  the query for 0:
# selected bidder id:9
# bidder 9 bidding:10 spent : 120/190 : [0, 8, 2]
#  the query for 1:
# bidders all inactive
#  the query for 1:
# bidders all inactive
#  the query for 3:
# bidders all inactive
#  the query for 7:
# selected bidder id:8
# bidder 8 bidding:14 spent : 196/406 : [4, 2, 7]
#  the query for 5:
# bidders all inactive
#  the query for 9:
# bidders all inactive
#  the query for 4:
# selected bidder id:8
# bidder 8 bidding:14 spent : 210/406 : [4, 2, 7]
#  the query for 8:
# selected bidder id:9
# bidder 9 bidding:10 spent : 130/190 : [0, 8, 2]
#  the query for 5:
# bidders all inactive
#  the query for 7:
# selected bidder id:8
# bidder 8 bidding:14 spent : 224/406 : [4, 2, 7]
#  the query for 2:
# selected bidder id:9
# bidder 9 bidding:10 spent : 140/190 : [0, 8, 2]
#  the query for 1:
# bidders all inactive
#  the query for 2:
# selected bidder id:9
# bidder 9 bidding:10 spent : 150/190 : [0, 8, 2]
#  the query for 0:
# selected bidder id:9
# bidder 9 bidding:10 spent : 160/190 : [0, 8, 2]
#  the query for 6:
# selected bidder id:7
# bidder 7 bidding:5 spent : 5/95 : [6, 2]
#  the query for 1:
# bidders all inactive
#  the query for 6:
# selected bidder id:7
# bidder 7 bidding:5 spent : 10/95 : [6, 2]
#  the query for 4:
# selected bidder id:8
# bidder 8 bidding:14 spent : 238/406 : [4, 2, 7]
#  the query for 0:
# selected bidder id:9
# bidder 9 bidding:10 spent : 170/190 : [0, 8, 2]
#  the query for 4:
# selected bidder id:8
# bidder 8 bidding:14 spent : 252/406 : [4, 2, 7]
#  the query for 5:
# bidders all inactive
#  the query for 6:
# selected bidder id:7
# bidder 7 bidding:5 spent : 15/95 : [6, 2]
#  the query for 4:
# selected bidder id:8
# bidder 8 bidding:14 spent : 266/406 : [4, 2, 7]
#  the query for 6:
# selected bidder id:7
# bidder 7 bidding:5 spent : 20/95 : [6, 2]
#  the query for 9:
# bidders all inactive
#  the query for 6:
# selected bidder id:7
# bidder 7 bidding:5 spent : 25/95 : [6, 2]
#  the query for 3:
# bidders all inactive
#  the query for 7:
# selected bidder id:8
# bidder 8 bidding:14 spent : 280/406 : [4, 2, 7]
#  the query for 5:
# bidders all inactive
#  the query for 5:
# bidders all inactive
#  the query for 7:
# selected bidder id:8
# bidder 8 bidding:14 spent : 294/406 : [4, 2, 7]
#  the query for 9:
# bidders all inactive
#  the query for 2:
# selected bidder id:9
# bidder 9 bidding:10 spent : 180/190 : [0, 8, 2]
# ...
# selected bidder id:8
# bidder 8 bidding:7 spent : 35/77 : [2, 1]
#  the query for 9:
# bidders all inactive
#  the query for 8:
# bidders all inactive
#  the query for 3:
# selected bidder id:2
# bidder 2 bidding:16 spent : 32/416 : [3, 1]
#  the query for 0:
# bidders all inactive
#  the query for 1:
# selected bidder id:8
# bidder 8 bidding:7 spent : 42/77 : [2, 1]
#  the query for 9:
# bidders all inactive
#  the query for 3:
# selected bidder id:2
# bidder 2 bidding:16 spent : 48/416 : [3, 1]
#  the query for 4:
# selected bidder id:0
# bidder 0 bidding:18 spent : 162/522 : [4, 7]
#  the query for 8:
# bidders all inactive
#  the query for 1:
# selected bidder id:8
# bidder 8 bidding:7 spent : 49/77 : [2, 1]
#  the query for 9:
# bidders all inactive
#  the query for 9:
# bidders all inactive
#  the query for 8:
# bidders all inactive
#  the query for 5:
# selected bidder id:1
# bidder 1 bidding:19 spent : 19/57 : [5, 3, 2]
#  the query for 1:
# selected bidder id:8
# bidder 8 bidding:7 spent : 56/77 : [2, 1]
#  the query for 0:
# bidders all inactive
#  the query for 4:
# selected bidder id:0
# bidder 0 bidding:18 spent : 180/522 : [4, 7]
#  the query for 3:
# selected bidder id:1
# bidder 1 bidding:19 spent : 38/57 : [5, 3, 2]
#  the query for 4:
# selected bidder id:0
# bidder 0 bidding:18 spent : 198/522 : [4, 7]
#  the query for 1:
# selected bidder id:8
# bidder 8 bidding:7 spent : 63/77 : [2, 1]
#  the query for 4:
# selected bidder id:0
# bidder 0 bidding:18 spent : 216/522 : [4, 7]
#  the query for 6:
# bidders all inactive
#  the query for 5:
# selected bidder id:1
# bidder 1 bidding:19 spent : 57/57 : [5, 3, 2]
#  the query for 9:
# bidders all inactive
#  the query for 1:
# selected bidder id:8
# bidder 8 bidding:7 spent : 70/77 : [2, 1]
#  the query for 1:
# selected bidder id:8
# bidder 8 bidding:7 spent : 77/77 : [2, 1]
#  the query for 4:
# selected bidder id:0
# bidder 0 bidding:18 spent : 234/522 : [4, 7]
#  the query for 1:
# selected bidder id:2
# bidder 2 bidding:16 spent : 64/416 : [3, 1]
#  the query for 4:
# selected bidder id:0
# bidder 0 bidding:18 spent : 252/522 : [4, 7]
#  the query for 8:
# bidders all inactive
#  the query for 1:
# selected bidder id:2
# bidder 2 bidding:16 spent : 80/416 : [3, 1]
#  the query for 4:
# selected bidder id:0
# bidder 0 bidding:18 spent : 270/522 : [4, 7]
#  the query for 8:
# bidders all inactive
#  the query for 9:
# bidders all inactive
#  the query for 8:
# bidders all inactive
#  the query for 3:
# selected bidder id:2
# bidder 2 bidding:16 spent : 96/416 : [3, 1]
#  the query for 7:
# selected bidder id:0
# bidder 0 bidding:18 spent : 288/522 : [4, 7]
#  the query for 2:
# bidders all inactive
#  the query for 9:
# bidders all inactive
#  the query for 1:
# selected bidder id:2
# bidder 2 bidding:16 spent : 112/416 : [3, 1]
#  the query for 1:
# selected bidder id:2
# bidder 2 bidding:16 spent : 128/416 : [3, 1]
#  the query for 5:
# bidders all inactive
#  the query for 3:
# selected bidder id:2
# bidder 2 bidding:16 spent : 144/416 : [3, 1]
#  the query for 5:
# bidders all inactive
#  the query for 7:
# selected bidder id:0
# bidder 0 bidding:18 spent : 306/522 : [4, 7]
#  the query for 6:
# bidders all inactive
#  the query for 9:
# bidders all inactive
#  the query for 0:
# bidders all inactive
#  the query for 5:
# bidders all inactive
#  the query for 6:
# bidders all inactive
#  the query for 1:
# selected bidder id:2
# bidder 2 bidding:16 spent : 160/416 : [3, 1]
#  the query for 8:
# bidders all inactive
#  the query for 6:
# bidders all inactive
#  the query for 0:
# bidders all inactive
#  the query for 2:
# bidders all inactive
#  the query for 3:
# selected bidder id:2
# bidder 2 bidding:16 spent : 176/416 : [3, 1]
#  the query for 4:
# selected bidder id:0
# bidder 0 bidding:18 spent : 324/522 : [4, 7]
#  the query for 4:
# selected bidder id:0
# bidder 0 bidding:18 spent : 342/522 : [4, 7]
#  the query for 2:
# bidders all inactive
# TOTAL GAINS IS 934
# bidder 0 bidding:2 spent : 0/32 : [8, 7, 9]
# bidder 1 bidding:4 spent : 0/68 : [9, 7, 5]
# bidder 2 bidding:8 spent : 0/168 : [4, 2, 5]
# bidder 3 bidding:14 spent : 0/182 : [9, 4, 0]
# bidder 4 bidding:12 spent : 0/300 : [1, 6, 2]
# bidder 5 bidding:12 spent : 0/144 : [4, 1, 8]
# bidder 6 bidding:18 spent : 0/522 : [7, 2]
# bidder 7 bidding:4 spent : 0/68 : [9, 5, 8]
# bidder 8 bidding:13 spent : 0/117 : [8, 7, 1]
# bidder 9 bidding:14 spent : 0/70 : [3, 6, 0]
#  the query for 1:
# selected bidder id:4
# bidder 4 bidding:12 spent : 12/300 : [1, 6, 2]
#  the query for 3:
# selected bidder id:9
# bidder 9 bidding:14 spent : 14/70 : [3, 6, 0]
#  the query for 2:
# selected bidder id:2
# bidder 2 bidding:8 spent : 8/168 : [4, 2, 5]
#  the query for 1:
# selected bidder id:4
# bidder 4 bidding:12 spent : 24/300 : [1, 6, 2]
#  the query for 3:
# selected bidder id:9
# bidder 9 bidding:14 spent : 28/70 : [3, 6, 0]
#  the query for 0:
# selected bidder id:9
# bidder 9 bidding:14 spent : 42/70 : [3, 6, 0]
#  the query for 7:
# selected bidder id:0
# bidder 0 bidding:2 spent : 2/32 : [8, 7, 9]
#  the query for 1:
# selected bidder id:4
# bidder 4 bidding:12 spent : 36/300 : [1, 6, 2]
#  the query for 2:
# selected bidder id:2
# bidder 2 bidding:8 spent : 16/168 : [4, 2, 5]
#  the query for 1:
# selected bidder id:4
# bidder 4 bidding:12 spent : 48/300 : [1, 6, 2]
#  the query for 3:
# selected bidder id:9
# bidder 9 bidding:14 spent : 56/70 : [3, 6, 0]
#  the query for 5:
# selected bidder id:1
# bidder 1 bidding:4 spent : 4/68 : [9, 7, 5]
#  the query for 0:
# selected bidder id:9
# bidder 9 bidding:14 spent : 70/70 : [3, 6, 0]
#  the query for 1:
# selected bidder id:4
# bidder 4 bidding:12 spent : 60/300 : [1, 6, 2]
#  the query for 6:
# selected bidder id:4
# bidder 4 bidding:12 spent : 72/300 : [1, 6, 2]
#  the query for 8:
# selected bidder id:0
# bidder 0 bidding:2 spent : 4/32 : [8, 7, 9]
#  the query for 7:
# selected bidder id:0
# bidder 0 bidding:2 spent : 6/32 : [8, 7, 9]
#  the query for 6:
# selected bidder id:4
# bidder 4 bidding:12 spent : 84/300 : [1, 6, 2]
#  the query for 4:
# selected bidder id:2
# bidder 2 bidding:8 spent : 24/168 : [4, 2, 5]
#  the query for 9:
# selected bidder id:0
# bidder 0 bidding:2 spent : 8/32 : [8, 7, 9]
#  the query for 0:
# selected bidder id:3
# bidder 3 bidding:14 spent : 14/182 : [9, 4, 0]
#  the query for 3:
# bidders all inactive
#  the query for 3:
# bidders all inactive
#  the query for 1:
# selected bidder id:4
# bidder 4 bidding:12 spent : 96/300 : [1, 6, 2]
#  the query for 4:
# selected bidder id:2
# bidder 2 bidding:8 spent : 32/168 : [4, 2, 5]
#  the query for 7:
# selected bidder id:0
# bidder 0 bidding:2 spent : 10/32 : [8, 7, 9]
#  the query for 2:
# selected bidder id:2
# bidder 2 bidding:8 spent : 40/168 : [4, 2, 5]
#  the query for 8:
# selected bidder id:0
# bidder 0 bidding:2 spent : 12/32 : [8, 7, 9]
#  the query for 1:
# selected bidder id:4
# bidder 4 bidding:12 spent : 108/300 : [1, 6, 2]
#  the query for 6:
# selected bidder id:4
# bidder 4 bidding:12 spent : 120/300 : [1, 6, 2]
#  the query for 4:
# selected bidder id:2
# bidder 2 bidding:8 spent : 48/168 : [4, 2, 5]
#  the query for 4:
# selected bidder id:2
# bidder 2 bidding:8 spent : 56/168 : [4, 2, 5]
#  the query for 9:
# selected bidder id:0
# bidder 0 bidding:2 spent : 14/32 : [8, 7, 9]
#  the query for 8:
# selected bidder id:0
# bidder 0 bidding:2 spent : 16/32 : [8, 7, 9]
#  the query for 2:
# selected bidder id:2
# bidder 2 bidding:8 spent : 64/168 : [4, 2, 5]
#  the query for 2:
# selected bidder id:2
# bidder 2 bidding:8 spent : 72/168 : [4, 2, 5]
#  the query for 2:
# selected bidder id:2
# bidder 2 bidding:8 spent : 80/168 : [4, 2, 5]
#  the query for 2:
# selected bidder id:2
# bidder 2 bidding:8 spent : 88/168 : [4, 2, 5]
#  the query for 4:
# selected bidder id:2
# bidder 2 bidding:8 spent : 96/168 : [4, 2, 5]
#  the query for 5:
# selected bidder id:2
# bidder 2 bidding:8 spent : 104/168 : [4, 2, 5]
#  the query for 2:
# selected bidder id:2
# bidder 2 bidding:8 spent : 112/168 : [4, 2, 5]
#  the query for 9:
# selected bidder id:0
# bidder 0 bidding:2 spent : 18/32 : [8, 7, 9]
#  the query for 0:
# selected bidder id:3
# bidder 3 bidding:14 spent : 28/182 : [9, 4, 0]
#  the query for 2:
# selected bidder id:2
# bidder 2 bidding:8 spent : 120/168 : [4, 2, 5]
#  the query for 8:
# selected bidder id:0
# bidder 0 bidding:2 spent : 20/32 : [8, 7, 9]
#  the query for 9:
# selected bidder id:0
# bidder 0 bidding:2 spent : 22/32 : [8, 7, 9]
#  the query for 2:
# selected bidder id:2
# bidder 2 bidding:8 spent : 128/168 : [4, 2, 5]
#  the query for 3:
# bidders all inactive
#  the query for 5:
# selected bidder id:2
# bidder 2 bidding:8 spent : 136/168 : [4, 2, 5]
#  the query for 4:
# selected bidder id:2
# bidder 2 bidding:8 spent : 144/168 : [4, 2, 5]
#  the query for 4:
# selected bidder id:2
# bidder 2 bidding:8 spent : 152/168 : [4, 2, 5]
#  the query for 6:
# selected bidder id:4
# bidder 4 bidding:12 spent : 132/300 : [1, 6, 2]
#  the query for 6:
# selected bidder id:4
# bidder 4 bidding:12 spent : 144/300 : [1, 6, 2]
#  the query for 4:
# selected bidder id:2
# bidder 2 bidding:8 spent : 160/168 : [4, 2, 5]
#  the query for 8:
# selected bidder id:0
# bidder 0 bidding:2 spent : 24/32 : [8, 7, 9]
#  the query for 3:
# bidders all inactive
#  the query for 9:
# selected bidder id:0
# bidder 0 bidding:2 spent : 26/32 : [8, 7, 9]
#  the query for 3:
# bidders all inactive
#  the query for 2:
# selected bidder id:2
# bidder 2 bidding:8 spent : 168/168 : [4, 2, 5]
#  the query for 5:
# selected bidder id:1
# bidder 1 bidding:4 spent : 8/68 : [9, 7, 5]
#  the query for 2:
# selected bidder id:4
# bidder 4 bidding:12 spent : 156/300 : [1, 6, 2]
#  the query for 5:
# selected bidder id:1
# bidder 1 bidding:4 spent : 12/68 : [9, 7, 5]
#  the query for 5:
# selected bidder id:1
# bidder 1 bidding:4 spent : 16/68 : [9, 7, 5]
#  the query for 6:
# selected bidder id:4
# bidder 4 bidding:12 spent : 168/300 : [1, 6, 2]
#  the query for 2:
# selected bidder id:4
# bidder 4 bidding:12 spent : 180/300 : [1, 6, 2]
#  the query for 6:
# selected bidder id:4
# bidder 4 bidding:12 spent : 192/300 : [1, 6, 2]
#  the query for 3:
# bidders all inactive
#  the query for 1:
# selected bidder id:4
# bidder 4 bidding:12 spent : 204/300 : [1, 6, 2]
#  the query for 3:
# bidders all inactive
#  the query for 2:
# selected bidder id:4
# bidder 4 bidding:12 spent : 216/300 : [1, 6, 2]
#  the query for 6:
# selected bidder id:4
# bidder 4 bidding:12 spent : 228/300 : [1, 6, 2]
#  the query for 7:
# selected bidder id:0
# bidder 0 bidding:2 spent : 28/32 : [8, 7, 9]
#  the query for 1:
# selected bidder id:4
# bidder 4 bidding:12 spent : 240/300 : [1, 6, 2]
#  the query for 2:
# selected bidder id:4
# bidder 4 bidding:12 spent : 252/300 : [1, 6, 2]
#  the query for 4:
# selected bidder id:3
# bidder 3 bidding:14 spent : 42/182 : [9, 4, 0]
#  the query for 6:
# selected bidder id:4
# bidder 4 bidding:12 spent : 264/300 : [1, 6, 2]
#  the query for 6:
# selected bidder id:4
# bidder 4 bidding:12 spent : 276/300 : [1, 6, 2]
#  the query for 9:
# selected bidder id:0
# bidder 0 bidding:2 spent : 30/32 : [8, 7, 9]
#  the query for 8:
# selected bidder id:0
# bidder 0 bidding:2 spent : 32/32 : [8, 7, 9]
#  the query for 9:
# selected bidder id:1
# bidder 1 bidding:4 spent : 20/68 : [9, 7, 5]
#  the query for 0:
# selected bidder id:3
# bidder 3 bidding:14 spent : 56/182 : [9, 4, 0]
#  the query for 7:
# selected bidder id:1
# bidder 1 bidding:4 spent : 24/68 : [9, 7, 5]
#  the query for 0:
# selected bidder id:3
# bidder 3 bidding:14 spent : 70/182 : [9, 4, 0]
#  the query for 5:
# selected bidder id:1
# bidder 1 bidding:4 spent : 28/68 : [9, 7, 5]
#  the query for 7:
# selected bidder id:1
# bidder 1 bidding:4 spent : 32/68 : [9, 7, 5]
#  the query for 2:
# selected bidder id:4
# bidder 4 bidding:12 spent : 288/300 : [1, 6, 2]
#  the query for 5:
# selected bidder id:1
# bidder 1 bidding:4 spent : 36/68 : [9, 7, 5]
#  the query for 3:
# bidders all inactive
#  the query for 4:
# selected bidder id:3
# bidder 3 bidding:14 spent : 84/182 : [9, 4, 0]
#  the query for 2:
# selected bidder id:4
# bidder 4 bidding:12 spent : 300/300 : [1, 6, 2]
#  the query for 3:
# bidders all inactive
#  the query for 1:
# selected bidder id:5
# bidder 5 bidding:12 spent : 12/144 : [4, 1, 8]
#  the query for 3:
# bidders all inactive
#  the query for 4:
# selected bidder id:3
# bidder 3 bidding:14 spent : 98/182 : [9, 4, 0]
#  the query for 3:
# bidders all inactive
#  the query for 8:
# selected bidder id:7
# bidder 7 bidding:4 spent : 4/68 : [9, 5, 8]
#  the query for 9:
# selected bidder id:1
# bidder 1 bidding:4 spent : 40/68 : [9, 7, 5]
#  the query for 0:
# selected bidder id:3
# bidder 3 bidding:14 spent : 112/182 : [9, 4, 0]
#  the query for 2:
# selected bidder id:6
# bidder 6 bidding:18 spent : 18/522 : [7, 2]
#  the query for 2:
# selected bidder id:6
# bidder 6 bidding:18 spent : 36/522 : [7, 2]
#  the query for 1:
# selected bidder id:5
# bidder 5 bidding:12 spent : 24/144 : [4, 1, 8]
#  the query for 8:
# selected bidder id:7
# bidder 7 bidding:4 spent : 8/68 : [9, 5, 8]
#  the query for 7:
# selected bidder id:1
# bidder 1 bidding:4 spent : 44/68 : [9, 7, 5]
#  the query for 0:
# selected bidder id:3
# bidder 3 bidding:14 spent : 126/182 : [9, 4, 0]
#  the query for 3:
# bidders all inactive
#  the query for 6:
# bidders all inactive
#  the query for 8:
# selected bidder id:7
# bidder 7 bidding:4 spent : 12/68 : [9, 5, 8]
#  the query for 7:
# selected bidder id:1
# bidder 1 bidding:4 spent : 48/68 : [9, 7, 5]
#  the query for 5:
# selected bidder id:1
# bidder 1 bidding:4 spent : 52/68 : [9, 7, 5]
#  the query for 2:
# selected bidder id:6
# bidder 6 bidding:18 spent : 54/522 : [7, 2]
#  the query for 5:
# selected bidder id:1
# bidder 1 bidding:4 spent : 56/68 : [9, 7, 5]
#  the query for 8:
# selected bidder id:7
# bidder 7 bidding:4 spent : 16/68 : [9, 5, 8]
#  the query for 7:
# selected bidder id:1
# bidder 1 bidding:4 spent : 60/68 : [9, 7, 5]
#  the query for 3:
# bidders all inactive
#  the query for 7:
# selected bidder id:1
# bidder 1 bidding:4 spent : 64/68 : [9, 7, 5]
#  the query for 1:
# selected bidder id:5
# bidder 5 bidding:12 spent : 36/144 : [4, 1, 8]
#  the query for 1:
# selected bidder id:5
# bidder 5 bidding:12 spent : 48/144 : [4, 1, 8]
#  the query for 0:
# selected bidder id:3
# bidder 3 bidding:14 spent : 140/182 : [9, 4, 0]
#  the query for 3:
# bidders all inactive
#  the query for 8:
# selected bidder id:7
# bidder 7 bidding:4 spent : 20/68 : [9, 5, 8]
#  the query for 7:
# selected bidder id:1
# bidder 1 bidding:4 spent : 68/68 : [9, 7, 5]
#  the query for 8:
# selected bidder id:7
# bidder 7 bidding:4 spent : 24/68 : [9, 5, 8]
#  the query for 3:
# bidders all inactive
#  the query for 8:
# selected bidder id:7
# bidder 7 bidding:4 spent : 28/68 : [9, 5, 8]
#  the query for 1:
# selected bidder id:5
# bidder 5 bidding:12 spent : 60/144 : [4, 1, 8]
#  the query for 0:
# selected bidder id:3
# bidder 3 bidding:14 spent : 154/182 : [9, 4, 0]
#  the query for 3:
# bidders all inactive
#  the query for 3:
# bidders all inactive
#  the query for 3:
# bidders all inactive
#  the query for 5:
# selected bidder id:7
# bidder 7 bidding:4 spent : 32/68 : [9, 5, 8]
#  the query for 4:
# selected bidder id:3
# bidder 3 bidding:14 spent : 168/182 : [9, 4, 0]
#  the query for 9:
# selected bidder id:3
# bidder 3 bidding:14 spent : 182/182 : [9, 4, 0]
#  the query for 9:
# selected bidder id:7
# bidder 7 bidding:4 spent : 36/68 : [9, 5, 8]
#  the query for 0:
# bidders all inactive
#  the query for 7:
# selected bidder id:8
# bidder 8 bidding:13 spent : 13/117 : [8, 7, 1]
#  the query for 9:
# selected bidder id:7
# bidder 7 bidding:4 spent : 40/68 : [9, 5, 8]
#  the query for 2:
# selected bidder id:6
# bidder 6 bidding:18 spent : 72/522 : [7, 2]
#  the query for 2:
# selected bidder id:6
# bidder 6 bidding:18 spent : 90/522 : [7, 2]
#  the query for 5:
# selected bidder id:7
# bidder 7 bidding:4 spent : 44/68 : [9, 5, 8]
#  the query for 8:
# selected bidder id:7
# bidder 7 bidding:4 spent : 48/68 : [9, 5, 8]
#  the query for 3:
# bidders all inactive
#  the query for 8:
# selected bidder id:7
# bidder 7 bidding:4 spent : 52/68 : [9, 5, 8]
#  the query for 1:
# selected bidder id:5
# bidder 5 bidding:12 spent : 72/144 : [4, 1, 8]
#  the query for 5:
# selected bidder id:7
# bidder 7 bidding:4 spent : 56/68 : [9, 5, 8]
#  the query for 9:
# selected bidder id:7
# bidder 7 bidding:4 spent : 60/68 : [9, 5, 8]
#  the query for 8:
# selected bidder id:7
# bidder 7 bidding:4 spent : 64/68 : [9, 5, 8]
#  the query for 4:
# selected bidder id:5
# bidder 5 bidding:12 spent : 84/144 : [4, 1, 8]
#  the query for 5:
# selected bidder id:7
# bidder 7 bidding:4 spent : 68/68 : [9, 5, 8]
#  the query for 8:
# selected bidder id:5
# bidder 5 bidding:12 spent : 96/144 : [4, 1, 8]
#  the query for 0:
# bidders all inactive
# TOTAL GAINS IS 1087
#  average gains is : 992
#  min gains is : 585
#  max gains is : 1353

# %%
# Out:
# -8
